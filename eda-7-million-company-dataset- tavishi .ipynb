# %% [markdown]
# # Exploratory Data Analysis Case Study - 7+ Million Companies Dataset
# ![](https://i.imgur.com/9adirQH.jpg)

# %% [markdown]
# **What is Exploratory Data Analysis?**
#
# Exploratory Data Analysis (EDA) is the process of exploring, investigating and gathering insights from data using statistical measures and visualizations. The objective of EDA is to develop and understanding of data, by uncovering trends, relationships and patterns.
#
# EDA is both a science and an art. On the one hand it requires the knowledge of statistics, visualization techniques and data analysis tools like Numpy, Pandas, Seaborn etc. On the other hand, it requires asking interesting questions to guide the investigation and interpreting numbers & figures to generate useful insights.

# %% [markdown]
# **Project Outline**
#
# - select and Downloada dataset from an online source
# - Data preparation and cleaning with Pandas
# - Open-ended exploratory analysis and visualization
# - Asking and answering interesting questions
# - Summarizing inferences and drawing conclusions

# %% [markdown]
# # How to Run the Code
#
# The best way to learn the material is to execute the code and experiment with it yourself. This tutorial is an executable [Jupyter notebook](https://jupyter.org). You can _run_ this tutorial and experiment with the code examples in a couple of ways: *using free online resources* (recommended) or *on your computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing the code is to click the **Run** button at the top of this page and select **Run on Binder**. You can also select "Run on Colab" or "Run on Kaggle", but you'll need to create an account on [Google Colab](https://colab.research.google.com) or [Kaggle](https://kaggle.com) to use these platforms.
#
#
# #### Option 2: Running on your computer locally
#
# To run the code on your computer locally, you'll need to set up [Python](https://www.python.org), download the notebook and install the required libraries. We recommend using the [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/) distribution of Python. Click the **Run** button at the top of this page, select the **Run Locally** option, and follow the instructions.

# %% [markdown]
# **Select and download real-world dataset**
#
# On Kaggle, this dataset is accessible. It includes details on the 7 million businesses that exist globally. It contains details about the companies' founding year, employment status, and the nations and places in which they are present. We'll examine this dataset and make some judgments.
#
# Dataset Link - https://www.kaggle.com/peopledatalabssf/free-7-million-company-dataset
#
# **Downloading the Dataset**
#
# There are several options for getting a dataset into Jupyter:
#
# - Download the CSV manually and upload it via Jupyter's GUI
# - Use the `urlretrieve` function from the `urllib.request` to download CSV files from a raw URL
# - Use the `opendatasets` library to download datasets from Kaggle datasets and Google Drive URLs
#
# Let's download the data into the Jupyter notebook. We'll use the opendatasets library. Let's install and import it, and use the download method.
#
# Use the "Run" button to execute the code.

# %% [markdown]
# # Install and Import all the required libraries.

# %%
# Data analysis library in python
import pandas as pd

# numerical computing library
import numpy as np

# for creating static visualizations in Python
import matplotlib
import matplotlib.pyplot as plt

# it turns on “inline plotting”, where plot graphics will appear in your notebook
# %matplotlib inline 
# a high-level interface for drawing informative statistical graphics.
import seaborn as sns

#for creating interactive visualizations
import plotly.express as px

#Plotting geospatial data with Folium
import folium

# to create wordcloud in python
import wordcloud

# %% [markdown]
# # Downloading a dataset from an online

# %%
# Install opendatsets library to downlaod the data from kaggle by using link of the data
# !pip install opendatasets --upgrade --quiet
import opendatasets as od 

#Kaggle Dataset URL
datasets_url = 'https://www.kaggle.com/peopledatalabssf/free-7-million-company-dataset'

# Downloading the dataset
od.download(datasets_url)
# Out:
# Skipping, found downloaded files in "./free-7-million-company-dataset" (use force=True to force download)

# %% [markdown]
# Let's verify that the dataset was downloaded into the directory `free-7-million-company-dataset ` and retrieve the list of files

# %%
# !ls -1h
# Out:
# comp_df.csv
# free-7-million-company-dataset
# sample_data

# %% [markdown]
# **Read the dataset**

# %% [markdown]
# Read the dataset using pandas library and convert the data into dataframe.

# %%
# %%time
df= pd.read_csv("free-7-million-company-dataset/companies_sorted.csv")
# Out:
# CPU times: user 22.5 s, sys: 5.57 s, total: 28.1 s
# Wall time: 29.1 s

# %%
df.head()
# Out:
#    Unnamed: 0                       name         domain  year founded  \
# 0     5872184                        ibm        ibm.com        1911.0
# 1     4425416  tata consultancy services        tcs.com        1968.0
# 2       21074                  accenture  accenture.com        1989.0
# 3     2309813                    us army     goarmy.com        1800.0
# 4     1558607                         ey         ey.com        1989.0
#
#                               industry size range  \
# 0  information technology and services     10001+
# 1  information technology and services     10001+
# 2  information technology and services     10001+
# 3                             military     10001+
# 4                           accounting     10001+
#
#                                  locality         country  \
# 0       new york, new york, united states   united states
# 1              bombay, maharashtra, india           india
# 2                 dublin, dublin, ireland         ireland
# 3     alexandria, virginia, united states   united states
# 4  london, greater london, united kingdom  united kingdom
#
#                                      linkedin url  current employee estimate  \
# 0                        linkedin.com/company/ibm                     274047
# 1  linkedin.com/company/tata-consultancy-services                     190771
# 2                  linkedin.com/company/accenture                     190689
# 3                    linkedin.com/company/us-army                     162163
# 4              linkedin.com/company/ernstandyoung                     158363
#
#    total employee estimate
# 0                   716906
# 1                   341369
# 2                   455768
# 3                   445958
# 4                   428960

# %% [markdown]
# # Data Preparation and Cleaning with Pandas.
#
# The quality of data is the most crucial element of any business intelligence strategy. Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data within a dataset.
#
# - Load the dataset into a data frame using Pandas
# - Explore the number of rows & columns, ranges of values etc.
# - Handle missing, incorrect and invalid datay of the missing values or - drop the values

# %% [markdown]
# **Some basic information about the data frame.**
#
# `shape`- gives you the information about the shape of rows and column.
#
# `info()`- gives you the information about the shape of rows and column. the datatype,and memory usage.
#
# `describe()` is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values.
#
# `df.coulums` gives u all the columns present in the dataset

# %%
df.shape
# Out:
# (7173426, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7173426 entries, 0 to 7173425
# Data columns (total 11 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Unnamed: 0                 int64
#  1   name                       object
#  2   domain                     object
#  3   year founded               float64
#  4   industry                   object
#  5   size range                 object
#  6   locality                   object
#  7   country                    object
#  8   linkedin url               object
#  9   current employee estimate  int64
#  10  total employee estimate    int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 602.0+ MB

# %% [markdown]
# **Observation:**
# The Dataset Contains-*italicized text*
#
# *   No of Rows- 7173426
# *   No of Columns- 11
# *   Datatype of each Columns- object,int64,float
# *   The file size 602.0+ MB
# *    Most columns have the data type `object`, either because they contain values of different types or contain empty values (`NaN`).

# %%
df.describe()
# Out:
#          Unnamed: 0  year founded  current employee estimate  \
# count  7.173426e+06  3.566446e+06               7.173426e+06
# mean   3.586712e+06  2.001747e+03               1.387121e+01
# std    2.070790e+06  2.096627e+01               3.545919e+02
# min    0.000000e+00  1.451000e+03               0.000000e+00
# 25%    1.793356e+06  1.999000e+03               1.000000e+00
# 50%    3.586712e+06  2.009000e+03               1.000000e+00
# 75%    5.380069e+06  2.013000e+03               4.000000e+00
# max    7.173425e+06  2.103000e+03               2.740470e+05
#
#        total employee estimate
# count             7.173426e+06
# mean              3.225438e+01
# std               8.741556e+02
# min               1.000000e+00
# 25%               1.000000e+00
# 50%               2.000000e+00
# 75%               7.000000e+00
# max               7.169060e+05

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'domain', 'year founded', 'industry',
#        'size range', 'locality', 'country', 'linkedin url',
#        'current employee estimate', 'total employee estimate'],
#       dtype='object')

# %% [markdown]
# **Drop all the coloumns which does't add value to the data.**

# %%
df_new=df.drop(['Unnamed: 0','domain','size range', 'linkedin url'], axis= 1)
df_new.head()
# Out:
#                         name  year founded  \
# 0                        ibm        1911.0
# 1  tata consultancy services        1968.0
# 2                  accenture        1989.0
# 3                    us army        1800.0
# 4                         ey        1989.0
#
#                               industry  \
# 0  information technology and services
# 1  information technology and services
# 2  information technology and services
# 3                             military
# 4                           accounting
#
#                                  locality         country  \
# 0       new york, new york, united states   united states
# 1              bombay, maharashtra, india           india
# 2                 dublin, dublin, ireland         ireland
# 3     alexandria, virginia, united states   united states
# 4  london, greater london, united kingdom  united kingdom
#
#    current employee estimate  total employee estimate
# 0                     274047                   716906
# 1                     190771                   341369
# 2                     190689                   455768
# 3                     162163                   445958
# 4                     158363                   428960

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7173426 entries, 0 to 7173425
# Data columns (total 7 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   name                       object
#  1   year founded               float64
#  2   industry                   object
#  3   locality                   object
#  4   country                    object
#  5   current employee estimate  int64
#  6   total employee estimate    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 383.1+ MB

# %% [markdown]
# **Observations:**
#
# Ater dripping the columns the size of the memory is reduced.
# The memory size of the was 602.0+ MB
# and now the memory size of the file is -383.1+ MB.

# %%
df1=df_new.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7173426 entries, 0 to 7173425
# Data columns (total 7 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   name                       object
#  1   year founded               float64
#  2   industry                   object
#  3   locality                   object
#  4   country                    object
#  5   current employee estimate  int64
#  6   total employee estimate    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 383.1+ MB

# %% [markdown]
# **Make some changes in dataframe to improve the readabilty**

# %%
# Renaming the columns
df1 = df1.rename(columns={"year founded": "year_founded","current employee estimate":"current_employee_estimate","total employee estimate":"total_employee_estimate"})

# Convert strings in the Series/Index to titlecase.
df1.name = df1.name.str.title()
df1.country = df1.country.str.title()
df1.industry = df1.industry.str.title()
df1.locality = df1.locality.str.title()

# %%
df1
# Out:
#                                    name  year_founded  \
# 0                                   Ibm        1911.0
# 1             Tata Consultancy Services        1968.0
# 2                             Accenture        1989.0
# 3                               Us Army        1800.0
# 4                                    Ey        1989.0
# ...                                 ...           ...
# 7173421              Certiport Vouchers        2011.0
# 7173422          Black Tiger Fight Club        2006.0
# 7173423      Catholic Bishop Of Chicago           NaN
# 7173424             Medexo Robotics Ltd           NaN
# 7173425  Dynamic Controls Solutions Inc           NaN
#
#                                     industry  \
# 0        Information Technology And Services
# 1        Information Technology And Services
# 2        Information Technology And Services
# 3                                   Military
# 4                                 Accounting
# ...                                      ...
# 7173421  Information Technology And Services
# 7173422         Health, Wellness And Fitness
# 7173423               Religious Institutions
# 7173424                             Research
# 7173425                           Automotive
#
#                                        locality         country  \
# 0             New York, New York, United States   United States
# 1                    Bombay, Maharashtra, India           India
# 2                       Dublin, Dublin, Ireland         Ireland
# 3           Alexandria, Virginia, United States   United States
# 4        London, Greater London, United Kingdom  United Kingdom
# ...                                         ...             ...
# 7173421                                     NaN             NaN
# 7173422                  Peking, Beijing, China           China
# 7173423      Inverness, Illinois, United States   United States
# 7173424          London, London, United Kingdom  United Kingdom
# 7173425          Wixom, Michigan, United States   United States
#
#          current_employee_estimate  total_employee_estimate
# 0                           274047                   716906
# 1                           190771                   341369
# 2                           190689                   455768
# 3                           162163                   445958
# 4                           158363                   428960
# ...                            ...                      ...
# 7173421                          0                        1
# 7173422                          0                        6
# 7173423                          0                        1
# 7173424                          0                        2
# 7173425                          0                        1
#
# [7173426 rows x 7 columns]

# %% [markdown]
# **Unique values in each column using unique method**
#
# The nuique () method returns the number of unique values for each column.

# %%
print("Number of unique values in column: ") 
for i in df1:
  count=len(df1[i].unique())
  print(i +" = "+ str(count))
# Out:
# Number of unique values in column:
# name = 7004634
# year_founded = 235
# industry = 149
# locality = 96245
# country = 237
# current_employee_estimate = 5379
# total_employee_estimate = 8486

# %% [markdown]
# # Open-ended exploratory analysis and visualization

# %% [markdown]
# **Find the missing values**
#
# **Missing(null) values using `isnull().sum()` method**
#
# The `isnull ()`- method returns a DataFrame object where all the values are replaced with a Boolean value True for NULL values, and otherwise False.
# But when you use sum(), it will return the sum of every column, which adds trues(=1) and false(= 0)

# %%
df1.isnull().sum()
# Out:
# name                               3
# year_founded                 3606980
# industry                      290003
# locality                     2508825
# country                      2349207
# current_employee_estimate          0
# total_employee_estimate            0
# dtype: int64

# %% [markdown]
# **Observation**:
# It appears that every column contains some empty values since the Non-Null count for every column is lower than the total number of rows (7173426). We'll need to deal with empty values and manually adjust the data type for each column on a case-by-case basis.

# %% [markdown]
# Columns name with missing (null) values

# %%
feature_with_na=[feature for feature in df1.columns if df1[feature].isnull().sum()>=1]
feature_with_na
# Out:
# ['name', 'year_founded', 'industry', 'locality', 'country']

# %% [markdown]
# **Percentage of missing(null) values**

# %%
for feature in feature_with_na:
    percentage_=np.round(df1[feature].isnull().mean()*100,4 )
    print("In Column " + feature,' missing values are ',+ percentage_ ,"%")
# Out:
# In Column name  missing values are  0.0 %
# In Column year_founded  missing values are  50.2825 %
# In Column industry  missing values are  4.0427 %
# In Column locality  missing values are  34.9739 %
# In Column country  missing values are  32.7487 %

# %%
# another way to do this Let's get the percentage of Null values
null_percentages = df1.isna().sum().sort_values(ascending=False)/len(df) * 100
null_percentages
# Out:
# year_founded                 50.282529
# locality                     34.973874
# country                      32.748745
# industry                      4.042741
# name                          0.000042
# current_employee_estimate     0.000000
# total_employee_estimate       0.000000
# dtype: float64

# %%
null_values=null_percentages[null_percentages != 0]
null_values
fig = px.bar(null_values,  
             title="Null Values Percentage ",        
             color_discrete_sequence=["#DAA520"])

fig.update_layout(font_size=18,
                  title_font_size=24,
                  title_font_color="black",
                  plot_bgcolor = "black",
                  showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8171ce3d-fe42-4b1b-a069-f41240fd18e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8171ce3d-fe42-4b1b-a069-f41240fd18e7")) {                    Plotly.newPlot(                        "8171ce3d-fe42-4b1b-a069-f41240fd18e7",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#DAA520","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["year_founded","locality","country","industry","name"],"xaxis":"x","y":[50.282528878112075,34.973874408128,32.74874516026233,4.042740525935585,4.182102108532241e-05],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter": ...

# %% [markdown]
# **The values and nan values with respect to 'total employee estimate'.**

# %%
data=df1.copy()
for feature in feature_with_na:
    
    #lets make a variable that indicates 1 if the observation was missing(if value is 0) or otherwise 
    data[feature]=np.where(data[feature].isnull(),1,0)
    
    #lets calculate the median where the information is missing or present 


    fig = px.bar(data.groupby(feature)['total_employee_estimate'].median(),  
             title="Values and null values count ",           
             color_discrete_sequence=["#2E8B57"])

    fig.update_layout(font_size=18,
                  title_font_size=24,
                  yaxis_title="Count",
                  title_font_color="black",
                  plot_bgcolor = "black",
                )
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a9f4388c-9db9-40d7-b4df-ade892e741b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9f4388c-9db9-40d7-b4df-ade892e741b8")) {                    Plotly.newPlot(                        "a9f4388c-9db9-40d7-b4df-ade892e741b8",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_employee_estimate<br>name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_employee_estimate","marker":{"color":"#2E8B57","pattern":{"shape":""}},"name":"total_employee_estimate","offsetgroup":"total_employee_estimate","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1],"xaxis":"x","y":[2.0,29.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="86626027-1de9-4094-b794-502b8c616600" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86626027-1de9-4094-b794-502b8c616600")) {                    Plotly.newPlot(                        "86626027-1de9-4094-b794-502b8c616600",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_employee_estimate<br>year_founded=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_employee_estimate","marker":{"color":"#2E8B57","pattern":{"shape":""}},"name":"total_employee_estimate","offsetgroup":"total_employee_estimate","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1],"xaxis":"x","y":[3.0,2.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fc08bc0c-0b83-4254-a987-6dfa8fab3a49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc08bc0c-0b83-4254-a987-6dfa8fab3a49")) {                    Plotly.newPlot(                        "fc08bc0c-0b83-4254-a987-6dfa8fab3a49",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_employee_estimate<br>industry=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_employee_estimate","marker":{"color":"#2E8B57","pattern":{"shape":""}},"name":"total_employee_estimate","offsetgroup":"total_employee_estimate","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1],"xaxis":"x","y":[2.0,1.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ti ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7ce18bec-4241-47f1-a247-21b6f0754c19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ce18bec-4241-47f1-a247-21b6f0754c19")) {                    Plotly.newPlot(                        "7ce18bec-4241-47f1-a247-21b6f0754c19",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_employee_estimate<br>locality=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_employee_estimate","marker":{"color":"#2E8B57","pattern":{"shape":""}},"name":"total_employee_estimate","offsetgroup":"total_employee_estimate","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1],"xaxis":"x","y":[3.0,2.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ti ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="354da377-2788-46e5-ba9d-c2efaff05b25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("354da377-2788-46e5-ba9d-c2efaff05b25")) {                    Plotly.newPlot(                        "354da377-2788-46e5-ba9d-c2efaff05b25",                        [{"alignmentgroup":"True","hovertemplate":"variable=total_employee_estimate<br>country=%{x}<br>value=%{y}<extra></extra>","legendgroup":"total_employee_estimate","marker":{"color":"#2E8B57","pattern":{"shape":""}},"name":"total_employee_estimate","offsetgroup":"total_employee_estimate","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1],"xaxis":"x","y":[3.0,2.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# **Fix the Missing values**

# %% [markdown]
# The column -
# year founded                 50.282529
# locality                     34.973874
# country                      32.748745
# industry                      4.042741
# NUll values data, you can fix the values will be the best option because if we will drop all the null values, then there will be loss of 64.65 percent of total loss to the data or you can drop the data.

# %%
print("The shape of data before dropping na values :")
df1.shape
# Out:
# The shape of data before dropping na values :
# (7173426, 7)

# %%
df1=df1.dropna()
print(df1.head(2))
# Out:
#                         name  year_founded  \
# 0                        Ibm        1911.0
# 1  Tata Consultancy Services        1968.0
#
#                               industry                           locality  \
# 0  Information Technology And Services  New York, New York, United States
# 1  Information Technology And Services         Bombay, Maharashtra, India
#
#          country  current_employee_estimate  total_employee_estimate
# 0  United States                     274047                   716906
# 1          India                     190771                   341369

# %%
df1.to_csv('comp_df.csv')

# %%
df1.isnull().sum()
# Out:
# name                         0
# year_founded                 0
# industry                     0
# locality                     0
# country                      0
# current_employee_estimate    0
# total_employee_estimate      0
# dtype: int64

# %% [markdown]
# ## Asking and answering interesting questions.
#
# 1 What is the corelation between the columns?
#
# 2-Name of the 15 companies has the maximumn current employees?
#
# 3-Find the companies establised before year 1800 and their country of origin?
#
# 4-Distribution of companies founded after 1800 year?
#
# 5- which industry has the most spread around the world?
#
# 6- what are the top 5 industries around the world?
#
# 7-How are the various industries distributed in the countrie in 21st century?
#
# 8-Create a TreeMap for countries in the data set?
#
# 9-which are the the Top 10 countries with the maximum companies?
#
# 10-Countries and their distributions in industries evolved over years?
#
# 11-Which country has more number of Medical industries with more employee?
#
# 12-what is the growth of the employees over the years?
#
# 13-Which city has more number of Medical industries with more number of employees within the country?
#
# 14-which company has most spread around the world?

# %% [markdown]
# ### Q1: Is there any correlation between the columns?

# %%
df1.corr()
# Out:
#                            year_founded  current_employee_estimate  \
# year_founded                   1.000000                  -0.075891
# current_employee_estimate     -0.075891                   1.000000
# total_employee_estimate       -0.076163                   0.976218
#
#                            total_employee_estimate
# year_founded                             -0.076163
# current_employee_estimate                 0.976218
# total_employee_estimate                   1.000000

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df1.corr(), annot=True, cmap="coolwarm", linewidths=2)

# %% [markdown]
# **Observations:**
# - From the above graph we can see that only 3 columns have correlation with each other and current employee and total employess have a strong correlation.

# %% [markdown]
# ### Q2: Name of the 15 companies has the maximumn current employees?

# %%
data1=df1.copy()
df_name_cemp =data1[data1['total_employee_estimate'] > 0]
df_name_cemp
# Out:
#                                        name  year_founded  \
# 0                                       Ibm          1911
# 1                 Tata Consultancy Services          1968
# 2                                 Accenture          1989
# 3                                   Us Army          1800
# 4                                        Ey          1989
# ...                                     ...           ...
# 7173404                   Squad Sp. Z O. O.          2013
# 7173411  Fuller, Hadeed, & Ros-Planas, Pllc          2015
# 7173416                     Fit Plus S.R.O.          1993
# 7173417                          Coriex Srl          1987
# 7173422              Black Tiger Fight Club          2006
#
#                                     industry  \
# 0        Information Technology And Services
# 1        Information Technology And Services
# 2        Information Technology And Services
# 3                                   Military
# 4                                 Accounting
# ...                                      ...
# 7173404                             Internet
# 7173411                         Law Practice
# 7173416         Health, Wellness And Fitness
# 7173417                    Apparel & Fashion
# 7173422         Health, Wellness And Fitness
#
#                                         locality         country  \
# 0              New York, New York, United States   United States
# 1                     Bombay, Maharashtra, India           India
# 2                        Dublin, Dublin, Ireland         Ireland
# 3            Alexandria, Virginia, United States   United States
# 4         London, Greater London, United Kingdom  United Kingdom
# ...                                          ...             ...
# 7173404           Litzmannstadt, Lodzkie, Poland          Poland
# 7173411  Virginia Beach, Virginia, United States   United States
# 7173416       Bratislava, Bratislavský, Slovakia        Slovakia
# 7173417                    Padova, Veneto, Italy           Italy
# 7173422                   Peking, Beijing, China           China
#
#          current_employee_estimate  total_employee_estimate
# 0                           274047                   716906
# 1                           190771                   341369
# 2                           190689                   455768
# 3                           162163                   445958
# 4                           158363                   428960
# ...                            ...                      ...
# 7173404                          0                        1
# 7173411                          0                        2
# 7173416                          0                        1
# 7173417                          0                        4
# 7173422                          0                        6
#
# [2684315 rows x 7 columns]

# %%
df_name_cemp =df_name_cemp[["name","current_employee_estimate"]]
df_name_cemp=df_name_cemp[:15]
df_name_cemp =df_name_cemp[["name","current_employee_estimate"]].sort_values('current_employee_estimate', ascending = True)
df_name_cemp
# Out:
#                               name  current_employee_estimate
# 15                            Citi                     101482
# 14                        Deloitte                     104112
# 13                         Infosys                     104752
# 11                             Pwc                     111372
# 10         United States Air Force                     113997
# 9                             At&T                     115188
# 8                        Microsoft                     116196
# 7                          Walmart                     120753
# 6   Cognizant Technology Solutions                     122031
# 5                  Hewlett-Packard                     127952
# 4                               Ey                     158363
# 3                          Us Army                     162163
# 2                        Accenture                     190689
# 1        Tata Consultancy Services                     190771
# 0                              Ibm                     274047

# %%
fig = px.histogram(df_name_cemp, y='name', x='current_employee_estimate',
                          hover_name='current_employee_estimate')

fig.update_layout(template='plotly_dark',
                 title="Top 15 countries with maximum current employee",
                 xaxis_title="Current Employee ",
                 yaxis_title="Companies",
                 showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="571f895c-1458-4861-8a5c-f4bc1ccbee1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("571f895c-1458-4861-8a5c-f4bc1ccbee1c")) {                    Plotly.newPlot(                        "571f895c-1458-4861-8a5c-f4bc1ccbee1c",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"sum of current_employee_estimate=%{x}<br>name=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"x":[101482,104112,104752,111372,113997,115188,116196,120753,122031,127952,158363,162163,190689,190771,274047],"xaxis":"x","y":["Citi","Deloitte","Infosys","Pwc","United States Air Force","At&T","Microsoft","Walmart","Cognizant Technology Solutions","Hewlett-Packard","Ey","Us Army","Accenture","Tata Consultancy Services","Ibm"],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram" ...

# %% [markdown]
# Observations:
# * IBM comes at the first position in total current employee and have more than 25000 employees as per the graph representation, and as per given data the exact number current employees are 274047
# * Tcs and Accentures comes at the second and 3rd and as per the given data the exact number of current employees are 190771	,190689 respectively.

# %% [markdown]
# **Analysis on Column ["year found"]**

# %% [markdown]
# Firstly change the datatype of column 'year founded'

# %%
df1['year_founded']= df1['year_founded'].astype(int)

# %%
df1['year_founded'].dtypes
# Out:
# dtype('int64')

# %%
df1['year_founded'].max()
# Out:
# 2103

# %% [markdown]
# The maximum value in the column 'year founded' is 2103 which is not possible, lets drop all the records from the data in the dataframe which is more than 2022 in column 'year founded'.

# %%
df1.index[df1['year_founded'] > 2022] # there are 5 records in the data which is greater that year 2022
# Out:
# Int64Index([478790, 1685181, 1911596, 2802880, 2939095], dtype='int64')

# %%
df1.drop(df1.index[df1["year_founded"]>2022],inplace =True)

# %% [markdown]
# Check wheather we have sucessfully removed all the record from the dataframe or not.

# %%
df1[df1['year_founded'] > 2022]
# Out:
# Empty DataFrame
# Columns: [name, year_founded, industry, locality, country, current_employee_estimate, total_employee_estimate]
# Index: []

# %%
df1.shape
# Out:
# (2684315, 7)

# %% [markdown]
# Observations:
# * Previoulsy the total number of rows  were 2684320,
# * After removing the data the total number of Rows are 2684315.

# %% [markdown]
# Let's look at the number of companies that were established before the 20th century.

# %%
df1[df1['year_founded']  < 1900]
# Out:
#                                               name  year_founded  \
# 3                                          Us Army          1800
# 9                                             At&T          1876
# 15                                            Citi          1812
# 17                            Jpmorgan Chase & Co.          1823
# 21                                         Siemens          1847
# ...                                            ...           ...
# 7165824                                  Quien&Cie          1877
# 7166941                       Griffin Stringer Ltd          1836
# 7168246  Institut Archéologique Du Luxembourg Asbl          1847
# 7170784               Advokatfirmaet Lars Meilvang          1899
# 7173367                            City Of Grenada          1836
#
#                                     industry  \
# 3                                   Military
# 9                         Telecommunications
# 15                        Financial Services
# 17                        Financial Services
# 21       Electrical/Electronic Manufacturing
# ...                                      ...
# 7165824                     Wine And Spirits
# 7166941               Environmental Services
# 7168246            Government Administration
# 7170784                       Legal Services
# 7173367              Paper & Forest Products
#
#                                              locality         country  \
# 3                 Alexandria, Virginia, United States   United States
# 9                        Dallas, Texas, United States   United States
# 15                  New York, New York, United States   United States
# 17                  New York, New York, United States   United States
# 21                           Munich, Bavaria, Germany         Germany
# ...                                               ...             ...
# 7165824          Bordeaux, Nouvelle-Aquitaine, France          France
# 7166941  Leicester, City Of Leicester, United Kingdom  United Kingdom
# 7168246                    Arlon, Luxembourg, Belgium         Belgium
# 7170784                  Auning, Midtjylland, Denmark         Denmark
# 7173367           Grenada, Mississippi, United States   United States
#
#          current_employee_estimate  total_employee_estimate
# 3                           162163                   445958
# 9                           115188                   269659
# 15                          101482                   298171
# 17                           95234                   242135
# 21                           87381                   240528
# ...                            ...                      ...
# 7165824                          0                        1
# 7166941                          0                        1
# 7168246                          0                        1
# 7170784                          0                        1
# 7173367                          0                        1
#
# [26005 rows x 7 columns]

# %% [markdown]
# There are 26005 companies are established before 20th century.

# %% [markdown]
# ### Q3: Find the companies establised before year 1800 and their country of origin?

# %%
data2= df1.copy()

data2.query("0 < `year_founded` < 1800")[['year_founded','name',"country","industry"]].reset_index(drop=True)
# Out:
#    year_founded                                    name         country  \
# 0          1789         U.S. Department Of The Treasury   United States
# 1          1451                   University Of Glasgow  United Kingdom
# 2          1775  Technology Services Organization (Tso)   United States
# 3          1799                        The Times Herald   United States
# 4          1775                Us Naval Reserve Officer   United States
# 5          1775          Marine Corps Officer Selection   United States
# 6          1789             White House Athletic Center   United States
# 7          1792                    Old Farmer'S Almanac   United States
#
#                                industry
# 0             Government Administration
# 1                              Research
# 2                     Computer Software
# 3                            Newspapers
# 4                       Defense & Space
# 5  Mechanical Or Industrial Engineering
# 6          Health, Wellness And Fitness
# 7                            Publishing

# %% [markdown]
# **Observations**:
# - There are only 8 companies estabished befor 1800 years in united states.

# %% [markdown]
# ### Q4-Distribution of companies founded after 1800 year?

# %% [markdown]
# The dataset is very large in size lets take only 20000 rows to do the analysis.

# %% [markdown]
# since we have very large dataset lets, lets drop all the null values.

# %% [markdown]
# The dataset is large in size lets take only 20000 row to get the insight of data.

# %%
sample_df1 = pd.read_csv('comp_df.csv',index_col = 0, nrows=25000)
sample_df1.head()
# Out:
#                         name  year_founded  \
# 0                        Ibm        1911.0
# 1  Tata Consultancy Services        1968.0
# 2                  Accenture        1989.0
# 3                    Us Army        1800.0
# 4                         Ey        1989.0
#
#                               industry  \
# 0  Information Technology And Services
# 1  Information Technology And Services
# 2  Information Technology And Services
# 3                             Military
# 4                           Accounting
#
#                                  locality         country  \
# 0       New York, New York, United States   United States
# 1              Bombay, Maharashtra, India           India
# 2                 Dublin, Dublin, Ireland         Ireland
# 3     Alexandria, Virginia, United States   United States
# 4  London, Greater London, United Kingdom  United Kingdom
#
#    current_employee_estimate  total_employee_estimate
# 0                     274047                   716906
# 1                     190771                   341369
# 2                     190689                   455768
# 3                     162163                   445958
# 4                     158363                   428960

# %%
sample_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25000 entries, 0 to 40217
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   name                       25000 non-null  object
#  1   year_founded               25000 non-null  float64
#  2   industry                   25000 non-null  object
#  3   locality                   25000 non-null  object
#  4   country                    25000 non-null  object
#  5   current_employee_estimate  25000 non-null  int64
#  6   total_employee_estimate    25000 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.5+ MB

# %%
#change the datatype of "year founded"
sample_df1 ["year_founded"]=sample_df1 ["year_founded"].astype(int)

# %%
df1_=sample_df1 [sample_df1 ['year_founded']>1800]
fig = px.histogram(df1_ , 
                   x='year_founded', 
                   marginal='box', 
                   color_discrete_sequence=['red'], 
                   title='Distribution of companies after 1800 Year.')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="320689e9-0a84-4598-bf97-7d18d010e81f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("320689e9-0a84-4598-bf97-7d18d010e81f")) {                    Plotly.newPlot(                        "320689e9-0a84-4598-bf97-7d18d010e81f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"year_founded=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"red","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[1911,1968,1989,1989,1939,1994,1962,1975,1876,1947,1998,1981,1900,1812,1968,1823,1994,1976,1847,1977,1865,1967,1945,1865,1998,1955,1916,1982,1945,1903,1968,1930,1984,1965,1962,1833,1991,1907,1848,1872,1866,1980,1987,1984,1830,1985,1926,1912,1971,1935,1977,1996,1887,1909,1836,1922,1969,1955,1892,1891,1862,1837,1901,1983,1946,1979,1986,2000,1848,1870,1998,1983,1987,1988,2003,2004,1939,1925,1949,1949,1980,1879,1896,1850,1938,1858,2008,1886,1976,1963,1919,1997,1892,1959,1891,1857,1832,1885,1931,1953,1856,1924,1927,1902,1906,1869,1946,1994,1999,2002,1987,1999,1972,1865,1966,1930,1892,1997,1864,1871,2014,1899,1933,1901,2014,1994,1928,1914,1903,1981,1947,1835,1928,1990,1947,1868,1924,1865,1999,1926,1963,1912,1963,1925,1947,1922,1864,1876,2009,1883,1956,1828,1919,1806,1923,1999,1942,1945,1955,1938,1935,1983,2015,1998,1919,2016,1999,1946,1897,1919,1853,1901,1994,1973,1922,1853,1885,2010,1923,1985,1947,1967,1980,1857,1923,1911,1955,1945,1862,1914,1890,1985,1837,1853,1957,1887,2008,2003,1911,1845,1867,1949,1987,1912,1938,1968,1968,1916,1802,2005,1921,2015,1962,1961,1977,1994,1906,1863,1935,1958,1857,1817,1974,2003,1993,1844,1858,1966,1902,2002,1943,1979,2005,1933,2006,2008,1928,1919,1930,1976,1958,1980,1817,1963,1884,1994,1982,2013,2006,1922,1878,1945,1939,1969,1890,1979,1872,1861,1999,2015,1980,1963,1993,1971,1941,1991,1902,1930,2005,1911,1976,1919,1922,1837,1817,1996,1917,1991,1884,1982,1844,1875,1957,1886,2002,1864,1998,1855,1930,1889,1931,1971,1959,1996,1872,2013,1828,1997,1976,1986,1906,2000,1948,1881,1946,1989,1982,1853,1880,1851,1851,1991,1922,1894,2014,1998,1960,1937,1870,1915,1978,1971,1919,1841,2000,2000,1957,1971,1961,1986,1865,1974,1937,1866,1888,1928,1882,1995,1946,1976,2009,1988,1897,1998,1998,1902,2007,1912,1904,1827,1983,1995,1971,1996,1806,2003,1957,1933,1915,1863,1987,1993,1973,1966,1887,1948,1967,1934,1997,1963,1958,1931,1963,1997,1999,2007,1917,1903,1823,1989,1876,1981,1885,1864,1972,1883,1869,1984,1960,2012,1997,1997,1891,1933,1986,1969,1855,2006,1926,1976,1853,1976,1986,1994,1919,1936,1946,1906,2000,1869,2008,1859,1867,1911,1880,1900,2001,1867,1968,1850,1975,1969,1989,1988,1876,1946,1833,2001,1941,1873,1873,1906,1884,1908,1971,1883,1872,1985,1862,1924,1810,1958,1831,1985,1998,1898,1858,1885,1982,1946,1868,1848,1980,1967,1817,1889,1950,1919,1928,1962,1954,1993,1999,1986,1927,1865,1983,1856,1958,1983,1990,1838,1935,1976,2002,1938,1998,1968,1841,1985,1946,1853,1967,1995,1971,1973,1907,1918,1993,1944,1840,1974,1837,1905,1996,1977,1966,1927,1954,1996,1894,1811,1950,1980,1997,1957,1945,1948,1898,1989,1976,1979,2006,1890,1939,1969,1946,1969,1981,1995,1861,1871,1987,1885,1828,2005,1976,1856,1969,1996,1976,1919,1975,1974,1985,2003,1960,1873,1960,1922,2008,1984,1979,1982,1915,1978,1826,1976,1946,1968,1979,1962,1944,1994,1911,1980,1948,1908,1945,1910,1999,1926,1837,1906,1988,1925,1986,1948,1975,2015,1962,1969,1889,1862,1850,1967,1961,1841,1887,1985,1994,1935,1956,1958,1939,1968,1934,1981,1981,1998,1983,1990,1971,1862,1969,1937,1970,1927,1976,2007,1820,1867,1943,1865,1928,1987,1884,1927,2000,1992,1849,1965,2000,1937,1986,2002,1944,1886,1905,2010,1919,1883,1983,1999,1935,1845,1879,1956,1996,1851,1895,2012,1986,1999,1902,1962,1918,1998,1874,1987,1983,1898,1948 ...

# %%
print("The mean of year founded is " ,df1_["year_founded"].mean())
print("The median of year founded  is ", df1_["year_founded"].median())
# Out:
# The mean of year founded is  1961.619794375325
# The median of year founded  is  1977.0

# %% [markdown]
# Observations:
# * Here our mean is somewhere around 1961 and median is 1977.
# * Most of the companies are established between 1946-2007.
#
# * Our chart is showing left-skewed distribution.(A "skewed left" distribution is one in which the tail is on the left side.)
#
# * If the histogram is skewed left, the mean is less than the median.This is the case because skewed-left data have a few small values that drive the mean downward but do not affect where the exact middle of the data is (that is, the median).

# %% [markdown]
# **Analysis on column ["Industry"**]

# %% [markdown]
# ### Q5: which industry has the most spread around the world?

# %%
data4=df1.copy()
from PIL import Image
from wordcloud import WordCloud
text = data4['industry'].values
wordcloud = WordCloud(width=800, height=400, background_color='black',).generate(str(text))
# Display the generated image:
# the matplotlib way:


plt.figure( figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show();

# %% [markdown]
# **observations:**
#
# From the above word cloud, we can analyze that Information Technology And Services, heath and wellness, are indusrtries has most spread around the world.

# %% [markdown]
# ### Q6: what are the top 5 industries around the world?

# %%
len(df["industry"].unique())
# Out:
# 149

# %% [markdown]
# observation: As per the data set there are total only 149 industry

# %%
data5 = sample_df1.copy() # this dataframe all the values agter dropping the null values from the real datadet
industry_df = data5['industry'].value_counts().rename_axis('industry').reset_index(name='count')
industry_df
# Out:
#                                 industry  count
# 0                       Higher Education   2093
# 1                 Hospital & Health Care   1550
# 2    Information Technology And Services   1395
# 3                     Financial Services    948
# 4                                 Retail    850
# ..                                   ...    ...
# 142                             Fine Art      3
# 143                 Alternative Medicine      2
# 144       Alternative Dispute Resolution      2
# 145                              Fishery      1
# 146                             Ranching      1
#
# [147 rows x 2 columns]

# %%
industy_df1=industry_df.nlargest(5, 'count').sort_values('count', ascending = True)
industy_df1
# Out:
#                               industry  count
# 4                               Retail    850
# 3                   Financial Services    948
# 2  Information Technology And Services   1395
# 1               Hospital & Health Care   1550
# 0                     Higher Education   2093

# %%
fig=px.bar(industry_df, y= industy_df1["industry"], x= industy_df1["count"],color=industy_df1["industry"],
                title="Top 5 Industries in the Whole World ")
fig.update_layout(yaxis_title='Industries', 
                  xaxis_title='Counts',
                  title_font_size=24,
                  title_font_color="Black",
                  font_size=14,
                  showlegend=False
)
fig.update_xaxes(color='Black')
fig.update_yaxes(color='Black')
fig.update_layout(plot_bgcolor="Black")
fig.update_layout(paper_bgcolor="#9ACD32")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ca725f34-2d44-4b94-939f-f305d5539465" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca725f34-2d44-4b94-939f-f305d5539465")) {                    Plotly.newPlot(                        "ca725f34-2d44-4b94-939f-f305d5539465",                        [{"alignmentgroup":"True","hovertemplate":"color=Retail<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Retail","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Retail","offsetgroup":"Retail","orientation":"h","showlegend":true,"textposition":"auto","x":[850],"xaxis":"x","y":["Retail"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Financial Services<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Financial Services","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Financial Services","offsetgroup":"Financial Services","orientation":"h","showlegend":true,"textposition":"auto","x":[948],"xaxis":"x","y":["Financial Services"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Information Technology And Services<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Information Technology And Services","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Information Technology And Services","offsetgroup":"Information Technology And Services","orientation":"h","showlegend":true,"textposition":"auto","x":[1395],"xaxis":"x","y":["Information Technology And Services"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Hospital & Health Care<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Hospital & Health Care","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Hospital & Health Care","offsetgroup":"Hospital & Health Care","orientation":"h","showlegend":true,"textposition":"auto","x":[1550],"xaxis":"x","y":["Hospital & Health Care"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Higher Education<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Higher Education","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Higher Education","offsetgroup":"Higher Education","orientation":"h","showlegend":true,"textposition":"auto","x":[2093],"xaxis":"x","y":["Higher Education"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f ...

# %% [markdown]
# **Observations:**
#
# Top 5 industries in the whole world are.
#
# 1. Higher Education
# 2. Hospital & Health Care
# 3. Information Technology And Services
# 4. Financial Services
# 5. Retail

# %% [markdown]
# ### Q7: How are the various industries distributed in the countrie in 21st century?

# %%
data_6 = sample_df1.copy()
data_6 = data_6[data_6["year_founded"] > 2000]
fig = px.scatter(data_6, 
                 x='industry', 
                 y='year_founded', 
                 color='country',  
                 hover_data=['total_employee_estimate'], 
                 title='Industries evloved over the years',
                 width=1200, height=600)
fig.update_traces(marker_size=5)
fig.update_traces(marker=dict(size=15,opacity = 0.7,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))

fig.update_layout(template="plotly",title='Distribution of industries in 21st century',
                 yaxis_title='Year from 1800 to 2016',
                 xaxis_title="Industry")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0886bfe9-fe26-43bc-8ce2-bd84cbc1fde7" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0886bfe9-fe26-43bc-8ce2-bd84cbc1fde7")) {                    Plotly.newPlot(                        "0886bfe9-fe26-43bc-8ce2-bd84cbc1fde7",                        [{"customdata":[[43622],[49059],[96521],[71654],[59821],[65277],[36867],[54041],[44812],[30571],[59118],[34168],[21393],[43070],[24703],[36290],[20194],[19222],[15944],[49836],[20739],[32767],[29073],[24318],[20133],[24428],[14707],[9401],[19483],[9180],[17442],[9803],[10750],[9567],[15176],[24153],[6743],[11315],[8774],[7633],[8654],[6696],[10075],[8182],[11339],[16046],[6288],[9116],[11810],[7995],[19551],[5679],[6109],[8985],[9706],[7332],[11366],[6583],[13779],[4903],[10160],[6505],[14685],[6113],[10854],[5147],[7875],[7396],[6027],[7715],[13826],[11423],[7882],[5035],[8405],[5211],[6107],[8080],[5286],[5937],[5072],[7179],[8174],[4367],[6114],[6561],[9528],[6194],[6038],[5440],[8075],[7219],[5720],[5781],[4442],[3687],[7590],[4273],[8252],[5776],[3564],[3866],[7769],[5306],[5722],[11889],[4799],[5570],[10392],[6633],[4335],[5173],[5968],[3863],[6323],[5369],[3265],[4876],[8507],[3753],[3458],[3932],[7950],[3571],[6285],[8945],[4257],[3447],[6713],[6280],[4999],[3603],[4047],[5404],[4766],[4952],[8091],[7224],[3079],[8873],[5888],[3783],[3079],[2818],[5920],[4032],[4966],[7659],[4257],[4333],[3309],[8520],[2564],[10958],[5367],[7112],[3134],[2848],[16000],[6819],[3193],[2669],[6501],[4002],[3456],[5159],[2194],[2474],[5546],[3439],[3467],[3276],[3525],[3044],[2820],[4087],[9021],[3403],[4330],[3583],[2290],[3354],[2408],[4170],[2048],[6960],[2296],[3294],[3586],[2373],[2744],[5564],[3154],[2582],[3634],[3336],[3930],[2735],[3115],[2794],[3154],[4362],[2650],[2962],[3338],[2892],[4350],[2522],[2802],[2823],[4988],[2643],[3675],[3822],[5139],[2233],[2193],[2552],[3534],[3037],[3999],[4833],[2734],[2260],[2097],[4255],[1638],[1704],[3701],[2157],[2788],[3233],[5070],[2816],[1973],[4004],[6260],[2119],[2559],[2796],[5074],[2574],[3071],[3510],[1619],[2492],[2048],[4304],[4484],[4232],[3447],[3069],[4772],[3953],[2195],[1515],[2463],[1807],[1652],[1608],[5172],[2813],[2778],[2037],[3024],[2668],[1987],[1656],[2340],[2474],[3920],[2978],[2160],[1961],[1753],[2732],[2184],[3326],[3591],[2402],[1859],[2901],[2113],[2494],[3410],[2287],[2541],[2284],[2327],[2919],[2358],[4032],[2484],[2333],[1973],[2195],[2848],[2150],[1971],[2452],[2687],[4423],[3139],[4638],[2314],[2071],[1556],[1875],[2129],[3026],[2035],[2450],[1931],[4441],[1761],[2143],[2289],[5743],[4497],[2171],[1857],[2124],[2455],[2024],[1278],[1873],[2862],[3256],[1981],[2709],[3356],[3228],[2727],[4872],[2158],[3208],[3051],[2571],[1781],[4637],[2311],[2510],[2662],[2438],[1456],[2316],[1247],[2142],[2265],[2480],[3290],[1377],[2583],[2171],[2314],[1625],[2020],[2310],[1913],[1397],[1631],[2746],[2018],[1164],[2205],[1868],[2025],[2038],[1142],[1495],[1582],[3242],[1243],[1348],[1704],[1705],[1714],[2543],[2065],[1889],[1777],[2314],[2162],[1571],[1655],[1853],[1831],[1782],[1908],[2511],[1723],[4102],[2260],[1592],[1530],[3341],[1499],[2258],[1544],[3357],[1593],[1105],[1717],[1078],[1570],[2042],[1155],[2041],[2507],[1759],[1541],[2449],[1689],[1596],[2156],[1854],[2532],[2027],[1227],[1199],[1561],[1382],[1433],[2010],[1410],[1171],[1517],[2445],[3409],[1890],[2681],[1633],[1722],[1828],[1696],[1646],[1663],[1841],[973],[1852],[2008],[1145],[1489],[1806],[1325],[2225],[2353],[3536],[1185],[2308],[1016],[1573],[1817],[1996],[1430],[1025],[1969],[2317],[1459],[1449],[2228],[1590],[1301],[3890],[1533],[2051],[1956],[1506],[1922],[1651],[2770],[1530],[1039],[1176],[1648],[1916],[1923],[1915],[1625],[1620],[2019],[1435],[1381],[1169], ...

# %% [markdown]
# Observations:
# - After 20th century the industries are rapidaly increasing.

# %% [markdown]
# Distribution of industries in india.

# %% [markdown]
# ![](https://i.imgur.com/kfZdenN.png)

# %% [markdown]
# Observations:
# - Individually we can check the distribution of the indusries  in specific country by clicking on the country name in the legand(country name fiven at the right side of the  above graph.)
# - We choose the accounting industry in legand and took the screenshot of that.
# - In United Kingdom and United States maximum indusrtries Accounting industries are evolved during years.

# %% [markdown]
# **Analysis on column ["locality"]**

# %% [markdown]
# ### Q8: Create a TreeMap for countries with maximum current employee in the data set?

# %% [markdown]
# Split the column locality

# %%
data9=sample_df1.copy()
data9[['city','state','country']] = data9.locality.apply(lambda x: pd.Series(str(x).split(", ")))

# %% [markdown]
# Convert strings in the Series/Index to titlecase.

# %%
data9.country = data9.country.str.title()
data9.city = data9.city.str.title()
data9.state = data9.state.str.title()

# %%
data9.isnull().sum()
# Out:
# name                         0
# year_founded                 0
# industry                     0
# locality                     0
# country                      0
# current_employee_estimate    0
# total_employee_estimate      0
# city                         0
# state                        0
# dtype: int64

# %%
fig = px.treemap(data9,
               path=["country","state","city"],
               values= "current_employee_estimate",
               color_continuous_scale="RdBu",
               title="Treemap of the countries with maximum employee")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="76618985-8c4b-4d45-99a0-4e76f9aa0273" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76618985-8c4b-4d45-99a0-4e76f9aa0273")) {                    Plotly.newPlot(                        "76618985-8c4b-4d45-99a0-4e76f9aa0273",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>current_employee_estimate=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Japan/Okinawa/A","Denmark/Syddanmark/A","Sweden/Vastra Gotaland/A","Spain/Galicia/A Coru\u00f1a","Denmark/Syddanmark/Aabenraa","Germany/North Rhine-Westphalia/Aachen","Lebanon/Mont-Liban/Aajaltoun","Denmark/Nordjylland/Aalborg","Germany/Baden-Wurttemberg/Aalen","Netherlands/North Holland/Aalsmeer","Switzerland/Aargau/Aarau","Switzerland/Aargau/Aarburg","Denmark/Central Jutland/Aarhus N","Belgium/Antwerpen/Aartselaar","Denmark/Syddanmark/Aaso","Italy/Veneto/Abano Terme","Canada/British Columbia/Abbotsford","Germany/Bayern/Abensberg","United Kingdom/Ceredigion/Aberaeron","United Kingdom/Aberdeen City/Aberdeen","United Kingdom/Aberdeenshire/Aberdeen","Saudi Arabia/'Asir/Abh\u0101","C\u00f4te D\u2019Ivoire/Lagunes/Abidjan","United States/Texas/Abilene","United States/Maryland/Abingdon","United Kingdom/Oxfordshire/Abingdon","United States/Virginia/Abingdon","Germany/Baden-W\u00fcrttemberg Region/Abstatt","United Arab Emirates/Abu Dhabi/Abu Dhabi","Nigeria/Fct/Abuja","Ghana/Greater Accra/Accra","United Kingdom/Lancashire/Accrington","Canada/Alberta/Acheson","United States/Massachusetts/Acton","United States/Georgia/Acworth","Kuwait/Al Kuwayt/Ad Dumna","United States/Michigan/Ada","United States/Ohio/Ada","United States/Oklahoma/Ada","United States/Iowa/Adair","Ethiopia/Adis Abeba/Addis Abeba","United States/Illinois/Addison","United States/Texas/Addison","Australia/South Australia/Adelaide","United States/Maryland/Adelphi","Lebanon/Mohafazat Mont-Liban/Adma","United States/Michigan/Adrian","Turkey/Afyonkarahisar/Afyonkarahisar","Cyprus/Limassol/Agios Athanasios","Greece/Attica/Agios Ioannis Rentis","Greece/Laconia/Agios Stefanos","United States/California/Agoura Hills","Brazil/Sao Paulo/Agua Branca","Mexico/Aguascalientes/Aguascalientes","Germany/North Rhine-Westphalia/Ahlen","Kuwait/Al Kuwayt/Ahmad","India/Gujarat/Ahmadabad","Canada/Alberta/Airdrie","Canada/Ontario/Ajax","United Arab Emirates/Ajman/Ajman","Japan/Kochi/Aki Gun","Norway/Hordaland/Akre","United States/Ohio/Akron","United States/Pennsylvania/Akron","Kazakhstan/West Kazakhstan/Aksay","United Arab Emirates/Abu Dhabi/Al Ain","Saudi Arabia/Eastern Province/Al A\u1e29s\u0101\u2019","Bahrain/Al Mintaqah Al Gharbiyah/Al Hamalah","Saudi Arabia/Ash Sharqiyah/Al Khobar","Kuwait/Al Kuwayt/Al Kuwait","Kuwait/Al Kuwayt/Al Shuwaikh","Saudi Arabia/Makkah/Al `Aziziyah","United States/Florida/Alachua","United States/California/Alameda","United States/California/Alamo","United States/Colorado/Alamosa","Spain/Castille-La Mancha/Albacete","Colombia/La Guajira/Albania","New Zealand/Auckland/Albany","United States/New York/Albany","United States/North Carolina/Albemarle","Denmark/Capital Region/Albertslund","United States/Alabama/Albertville","United States/Michigan/Albion","Australia/Queensland/Albion","United Kingdom/West Sussex/Albourne","United States/New Mexico/Albuquerque","Spain/Madrid/Alcobendas","Spain/Madrid/Alcorcon","United States/Oklahoma/Alderson","Egypt/Al Iskandariyah/Alexandria","United States/Minnesota/Alexandria","Australia/New South Wales/Alexandria","United States/Virginia/Alexandria","United States/New York/Alfred","United Kingdom/Derbyshire/Alfreton","Algeria/Alger/Algiers","United States/California/Alhambra","Turkey/I\u0307Zmir/Aliaga","Spain/V ...

# %% [markdown]
# **Observations:**
#
# - United states has maximum number around 60% of current employees.

# %% [markdown]
# **Analysis on Column ["Country"]**

# %% [markdown]
# ### Q9: Which are the Top 10 countries with the maximum companies?

# %%
data6=sample_df1.copy()
country_df = data6['country']
country_df
# Out:
# 0         United States
# 1                 India
# 2               Ireland
# 3         United States
# 4        United Kingdom
#               ...
# 40213     United States
# 40214     United States
# 40215       Netherlands
# 40216     United States
# 40217     United States
# Name: country, Length: 25000, dtype: object

# %%
data6=sample_df1.copy()
country_df = data6['country'].value_counts().rename_axis('country').reset_index(name='count')
country_df
# Out:
#             country  count
# 0     United States  12149
# 1    United Kingdom   1760
# 2             India   1097
# 3            Canada    917
# 4            Brazil    721
# ..              ...    ...
# 140        Dominica      1
# 141          Monaco      1
# 142         Grenada      1
# 143        Botswana      1
# 144        Mongolia      1
#
# [145 rows x 2 columns]

# %%
country_df1=country_df.nlargest(10, 'count').sort_values('count', ascending = True)
country_df1
# Out:
#           country  count
# 9           Spain    419
# 8           Italy    439
# 7       Australia    471
# 6     Netherlands    654
# 5          France    711
# 4          Brazil    721
# 3          Canada    917
# 2           India   1097
# 1  United Kingdom   1760
# 0   United States  12149

# %%
fig=px.bar(country_df,
           y= country_df1["country"],
           x= country_df1["count"],
           color=country_df1["country"],
                title="Top 10 countries with maximum companies")
fig.update_layout(yaxis_title='companies', 
                  xaxis_title='Counts',
                  title_font_size=24,
                  title_font_color="Blue",
                  font_size=14,
)
fig.update_xaxes(color='Black')
fig.update_yaxes(color='Black')
fig.update_layout(plot_bgcolor="Black")
fig.update_layout(paper_bgcolor="YellowGreen")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c84e56cf-af40-45fd-8b1b-a33b31b005a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c84e56cf-af40-45fd-8b1b-a33b31b005a9")) {                    Plotly.newPlot(                        "c84e56cf-af40-45fd-8b1b-a33b31b005a9",                        [{"alignmentgroup":"True","hovertemplate":"color=Spain<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Spain","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Spain","offsetgroup":"Spain","orientation":"h","showlegend":true,"textposition":"auto","x":[419],"xaxis":"x","y":["Spain"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Italy<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Italy","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"h","showlegend":true,"textposition":"auto","x":[439],"xaxis":"x","y":["Italy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Australia<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"h","showlegend":true,"textposition":"auto","x":[471],"xaxis":"x","y":["Australia"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Netherlands<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Netherlands","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Netherlands","offsetgroup":"Netherlands","orientation":"h","showlegend":true,"textposition":"auto","x":[654],"xaxis":"x","y":["Netherlands"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=France<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"France","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"h","showlegend":true,"textposition":"auto","x":[711],"xaxis":"x","y":["France"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Brazil<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"h","showlegend":true,"textposition":"auto","x":[721],"xaxis":"x","y":["Brazil"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Canada<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Canada","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":[917],"xaxis":"x","y":["Canada"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=India<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[1097],"xaxis":"x","y":["India"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=United Kingdom<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"United Kingdom","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"United Kingdom","offsetgroup":"United Kingdom","orientation":"h","showlegend":true,"textposition":"auto","x":[1760],"xaxis":"x","y":["United Kingdom"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=United States<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":[12149],"xaxis":"x","y":["United States"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"erro ...

# %% [markdown]
# **Observations:**
# - United states has maximum number of employess followed by United Kingdom  India, Canada, Brazil, France, Netherland, Australia, Italy, Spain, Germany.
# Observations:

# %% [markdown]
# ### Q10: Countries and their distributions in industries evolved over years?

# %%
data_7=sample_df1.copy()

fig = px.scatter(data_7, 
                 x='country',
                 y="year_founded",
                 color='industry',  
                hover_data=['year_founded'], 
                 title='industry',
                 width=1200, height=600)
fig.update_traces(marker_size=5)
fig.update_traces(marker=dict(size=15,opacity = 0.7,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))

fig.update_layout(template="plotly",title='Accounting industry and their distribution in the countries evolved over years.',
                 yaxis_title='Year',
                 xaxis_title="country")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c2c46f88-a357-44a8-9a2e-c9d9cbf99281" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2c46f88-a357-44a8-9a2e-c9d9cbf99281")) {                    Plotly.newPlot(                        "c2c46f88-a357-44a8-9a2e-c9d9cbf99281",                        [{"hovertemplate":"industry=Information Technology And Services<br>country=%{x}<br>year_founded=%{y}<extra></extra>","legendgroup":"Information Technology And Services","marker":{"color":"#636efa","symbol":"circle","size":15,"line":{"color":"DarkSlateGrey","width":2},"opacity":0.7},"mode":"markers","name":"Information Technology And Services","showlegend":true,"x":["United States","India","Ireland","United States","United States","India","United States","France","India","India","United States","United States","India","United States","United States","Canada","France","United States","United States","United States","France","Australia","United States","United States","India","United States","Spain","United States","India","India","United States","India","India","United States","Germany","United States","United States","South Africa","United States","United States","United States","India","United States","United States","United States","Finland","United States","United States","United States","Spain","France","United States","United States","United States","United States","United States","United States","India","Brazil","United States","United States","United States","India","Switzerland","India","United States","United States","United States","India","Netherlands","United States","India","United Kingdom","India","India","United States","France","India","United States","United States","United States","United States","Mexico","United States","India","India","India","United States","United States","Singapore","Argentina","Chile","Indonesia","United States","India","Italy","United States","United States","United States","France","United States","India","France","United States","Japan","United Kingdom","United Kingdom","United States","United States","United States","United States","South Korea","United States","Israel","United States","United States","Brazil","United States","United States","France","United States","United States","United Kingdom","United States","France","United States","United States","India","South Africa","Japan","New Zealand","India","United States","Hong Kong","United States","United States","Denmark","India","United States","Germany","United States","United States","United States","Norway","United States","United Kingdom","Brazil","United States","United Kingdom","Singapore","Spain","United States","United States","United Kingdom","United States","India","China","United States","United States","United States","China","United States","India","United States","Germany","India","United States","Italy","United Kingdom","United Kingdom","United States","United States","France","United States","United States","United States","South Africa","United States","Germany","Canada","Spain","United States","Netherlands","India","Australia","Norway","Finland","Netherlands","United States","United States","United States","Switzerland","Australia","United States","United States","United States","United States","United States","United States","United States","India","United Kingdom","United States","India","France","United States","India","United States","India","France","United States","Australia","United States","United States","China","China","France","South Africa","United States","United States","Brazil","China","France","Germany","Russia","South Korea","United Kingdom","United States","Estonia","Mexico","United States","Netherlands","United States","Netherlands","United States","Canada ...

# %% [markdown]
# Observation:
# * Individually we can check the distribution of the indusries by clicking on the industry name in the legand(insdustry written on the right side of the graph)
# * We choose the accounting industry in legand and took the screenshot of that.
# * In United Kingdom and United States maximum indusrtries Accounting industries are evolved over years.

# %% [markdown]
# **Accounting industry and their distribution in the contries evolved over years.**

# %% [markdown]
# # ![](https://i.imgur.com/t6UxpFL.png)

# %% [markdown]
# ### Q11: Which country has more number of Medical industries with more employees?

# %%
Medical_industry=[
'Hospital & Health Care',
'Public Policy',
'Alternative Medicine',
'Mental Health Care',
'Philanthropy',
'Veterinary',
'Medical Practice',
'Insurance''Cosmetics',
'Health, Wellness And Fitness', 
'Hospitality',
'Human Resources', 
'Medical Devices', 
'Biotechnology',
'Cosmetics']

# %%
Medical_df= data9[data9.industry.isin(Medical_industry)]
Medical_df
# Out:
#                               name  year_founded                industry  \
# 35               Kaiser Permanente          1945  Hospital & Health Care
# 49              Unitedhealth Group          1980  Hospital & Health Care
# 66               Johnson & Johnson          1887  Hospital & Health Care
# 75                         Philips          1891  Hospital & Health Care
# 101                            Adp          1949         Human Resources
# ...                            ...           ...                     ...
# 40036  Monte Carlo Resort & Casino          1996             Hospitality
# 40058   Home Health & Hospice Care          1883  Hospital & Health Care
# 40074           Community Care Inc          1977  Hospital & Health Care
# 40160                 Molton Brown          1973               Cosmetics
# 40183          Gordon Ramsay Group          1998             Hospitality
#
#                                        locality         country  \
# 35           Oakland, California, United States   United States
# 49        Minneapolis, Minnesota, United States   United States
# 66     New Brunswick, New Jersey, United States   United States
# 75            Guildford, Surrey, United Kingdom  United Kingdom
# 101         Roseland, New Jersey, United States   United States
# ...                                         ...             ...
# 40036          Las Vegas, Nevada, United States   United States
# 40058   Merrimack, New Hampshire, United States   United States
# 40074      Brookfield, Wisconsin, United States   United States
# 40160    London, Greater London, United Kingdom  United Kingdom
# 40183            London, London, United Kingdom  United Kingdom
#
#        current_employee_estimate  total_employee_estimate           city  \
# 35                         65839                   105240        Oakland
# 49                         57720                   103293    Minneapolis
# 66                         43985                   118073  New Brunswick
# 75                         41732                   115665      Guildford
# 101                        35686                    81555       Roseland
# ...                          ...                      ...            ...
# 40036                        291                      840      Las Vegas
# 40058                        290                      412      Merrimack
# 40074                        290                      485     Brookfield
# 40160                        290                     1066         London
# 40183                        289                     1578         London
#
#                 state
# 35         California
# 49          Minnesota
# 66         New Jersey
# 75             Surrey
# 101        New Jersey
# ...               ...
# 40036          Nevada
# 40058   New Hampshire
# 40074       Wisconsin
# 40160  Greater London
# 40183          London
#
# [2731 rows x 9 columns]

# %%
 
Medical_df = Medical_df[:200]

fig = px.histogram(Medical_df, x='city', y='total_employee_estimate',
                        
                          color='country', 
                          hover_name='city')

fig.update_layout(template='plotly_dark',
                 title="Medical Industry in different cities",
                 yaxis_title="Total out of 200",
                 xaxis_title="Cities around the world", 
                 legend_title ='Name of Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c2b4be8a-9667-4837-9d84-407fdffc2d97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2b4be8a-9667-4837-9d84-407fdffc2d97")) {                    Plotly.newPlot(                        "c2b4be8a-9667-4837-9d84-407fdffc2d97",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country=United States<br>city=%{x}<br>sum of total_employee_estimate=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"x":["Oakland","Minneapolis","New Brunswick","Roseland","Minneapolis","Illinois City","New York","Bethesda","Addison","Danbury","Mclean","Providence","Los Angeles","Nashville","Cleveland","Marlborough","Thousand Oaks","Santa Clara","Kalamazoo","Waltham","Bloomfield","Deerfield","Dublin","South San Francisco","Franklin Lakes","Denver","Renton","San Francisco","Stamford","Madison","Phoenix","Pittsburgh","Plano","Boston","Lake Success","Chicago","New York","Houston","Murray","Louisville","Rochester","Charlotte","New York","Warsaw","St. Louis","Orlando","New York","Chesterfield","Lehi","Grand Rapids","Orlando","Palmetto","Columbia","Addison","New York","Portland","Dallas","Downers Grove","Brentwood","Foster City","Cambridge","Kennett Square","Arlington","Cleveland","Scottsdale","Philadelphia","Irvine","Charleston","Boston","Scottsdale","Detroit","Cambridge","Stamford","Santa Monica","San Ramon","Marriottsville","Saint Louis","Taylor","Columbus","Baltimore","Lake Mary","Los Angeles","Chanhassen","Dallas","Summit","Idaho Falls","Charlotte","New Orleans","Stanford","Chandler","Ann Arbor","Mclean","Chicago","Aurora","Lincolnshire","New York","Long Beach","New York","Salt Lake City","Houston","Altamonte Springs","Franklin","Marietta","Indianapolis","Melville","Orlando","Galveston","King Of Prussia","Minneapolis","Irvine","Irving","Tarrytown","Seattle","Columbus","Clearwater","San Diego","Dallas","Bethlehem","San Diego","Mundelein","Greenwood Village","Portland","Columbus","Durham","Chapel Hill","Bucks","Orlando","Wilmington","Columbus","Englewood","New Haven","Buffalo","Bridgewater","Dallas","Mclean","Indianapolis","Newark","Palo Alto","Evanston","Atlanta","Hallandale","Phoenix","Allentown","Hastings","Hercules","Little Rock","Las Vegas","Orange","Louisville","Somerville","Baltimore","San Diego","Baton Rouge","Greenville","New York","Chicago","St. Louis","Orlando","St. Louis"],"xaxis":"x","y":[105240,103293,118073,81555,68465,95035,64294,79978,33206,44812,56818,23426,27470,31543,32174,40046,38225,35128,32299,26649,34258,45885,32851,27340,28654,20261,19884,26683,43413,22332,17475,21652,11457,25404,15987,26029,25217,18163,15063,18259,20664,14989,18045,17621,19217,30561,16589,13007,9013,12790,13931,9401,17720,9180,16400,14632,12501,10888,13650,12132,17070,11995,10302,11631,15176,13281,19704,11970,15841,6743,11114,15065,22877,8262,19913,9812,8677,8892,11382,13597,16787,11527,14604,13255,9393,7951,8835,8411,10547,6288,11430,12132,11262,8664,10065,9116,8777,12039,6422,8317,5679,9446,8056,9295,8506,8053,8687,7949,8313,8592,8139,6654,8382,7787,7096,7548,12936,8576,7554,7570,9781,9821,6774,8188,8594,9669,10282,8650,8206,7176,7694,11414,13541,7573,12857,9409,7270,6999,7269,6538,5211,13013,6821,8080,8655,6717,7892,6482,7785,7921,7835,6139,7129,5993,9082,8871,5989,8605,8161],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country=United Kingdom<br>city=%{x}<br>sum of total_employee_estimate=%{y}<extra></extra>","legendgroup":"United Kingdom","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United Kingdom","offsetgr ...

# %% [markdown]
# Observations:
#
# * In United state- Minneapolis and New york has maximum number of Medical indusries.
# * In United kingdom - Guildford has maximum number of Medical indusries.
# * In Switzerland- Basil has maximum number of Medical indusries.
# * In Netherland- Noord has maximum number of Medical indusries.
# * In Freance- Pris has maximum number of Medical indusries.
# * In India - chennai has maximum number of Medical indusries.

# %% [markdown]
# ### Q12: what is the growth of the employees over the years?

# %%
data_8=df1 [df1 ['year_founded']>1700]
fig = px.histogram(data_8, 
                 x="year_founded", 
                 y="total_employee_estimate", 
                 color= "year_founded",
                 color_discrete_sequence=['purple'], 
                 hover_data=['total_employee_estimate'], 
                 title='Growth of the employees over the years')
fig.update_layout(bargap=0.1,
                showlegend=False,
                yaxis_title="Current Employee count",
                xaxis_title="year")
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Observations:**
# - From the above graph, we can see that in year 1800 there were less than 0.2 million employess, in today in 21st century the current employese are more than 3 million.

# %% [markdown]
# ### Q13: Which city has more number of Medical industries with more number of employees within the country?

# %%
Medical_df = Medical_df[:200]

fig = px.histogram(Medical_df, x='country', y='total_employee_estimate',
                        
                          color='country', 
                          hover_name='city')

fig.update_layout(template='plotly_dark',
                 title="Medical Industry in different countries",
                 yaxis_title="Total out of 200",
                 xaxis_title="Countries", 
                 legend_title ='Name of Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="189fb134-b297-449e-a9c4-162b760e2df2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("189fb134-b297-449e-a9c4-162b760e2df2")) {                    Plotly.newPlot(                        "189fb134-b297-449e-a9c4-162b760e2df2",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country=%{x}<br>sum of total_employee_estimate=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"x":["United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],"xaxis":"x","y":[105240,103293,118073,81555,68465,95035,64294,79978,33206,44812,56818,23426,27470,31543,32174,40046,38225,35128,32299,26649,34258,45885,32851,27340,28654,20261,19884,26683,43413,22332,17475,21652,11457,25404,15987,26029,25217,18163,15063,18259,20664,14989,18045,17621,19217,30561,16589,13007,9013,12790,13931,9401,17720,9180,16400,14632,12501,10888,13650,12132,17070,11995,10302,11631,15176,13281,19704,11970,15841,6743,11114,15065,22877,8262,19913,9812,8677,8892,11382,13597,16787,11527,14604,13255,9393,7951,8835,8411,10547,6288,11430,12132,11262,8664,10065,9116,8777,1203 ...

# %% [markdown]
# **Observations:**
# - The united state has maximum no of medical industries around 2.7 millions, followed by united kindom has the around 0.3 million and other than this almost all the other countries has less than 0.2 of medical industries.

# %% [markdown]
# ### Q14: Which company has most spread around the world?

# %%
data10=df1.copy()
from PIL import Image
from wordcloud import WordCloud
text = data10["name"].values
wordcloud = WordCloud(width=800, height=400, background_color='black',).generate(str(text))
# Display the generated image:
# the matplotlib way:


plt.figure( figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show();

# %% [markdown]
# **Observations:**
# - The company Ibm has most spread around the world.

# %% [markdown]
# # **Summary**
# - Only 8 companies are established before 1800 in United states.
# - Most countries are established around 1967 to 1997 around the world.
# - Most of the companies are established in the United States followed by UK and India.
# - From the chart, we can see that in year 1800 there were less than 0.2 million employess, in today in 21st century the current employese are more than 3 million.
# -The united state has maximum no of medical industries around 2.7 millions, followed by united kindom has the around 0.3 million and other than this almost all the other countries has less than 0.2 of medical industries.
# -In United state Minneapolis and New york has maximum number of Medical indusries.
# -In United kingdom Guildford has maximum number of Medical indusries.
# - In India - chennai has maximum number of Medical indusries.
# - IBM, tata, Accenture are the companies with maximum current employees,IBM comes at the first position in total current employee and have more than 25000 employees as per the graph representation, and as per given data the exact number current employees are 274047
# Tcs and Accentures comes at the second and 3rd and as per the given data the exact number of current employees are 190771 ,190689 respectively.
# - India which is 4th highest contributing to 4 % of total companies in the world
# - From the chart, we can see that the higher education sector is among the top top 5 industries followed by hospital and health care, IT, financial services, amd retails
# - Insurance is contributing around 3 % all over the world.

# %% [markdown]
# # **Future work**
#
# - Visualize the cities where industries are located around the world
# Get the colorful map and try different columns.
# - Visualize the countries on world map.
# - We can do stratified sampling for every country.
# - More analysis can be drawn out from this dataset. As we haven't used all columns in analaysis. If we can combine more columns , more interesting result will come out.
# - We can also combine with some other interesting dataset .

# %% [markdown]
# # Reference
#
#
# Check out the following resources to learn more about the dataset and tools used in this notebook:
#
# - Pandas user guide: https://pandas.pydata.org/docs/user_guide/index.html
# - Matplotlib user guide: https://matplotlib.org/3.3.1/users/index.html
# - Seaborn user guide & tutorial: https://seaborn.pydata.org/tutorial.html
# - plotly user guide and tutorial https://plotly.com/python/
# - `opendatasets` Python library: https://github.com/JovianML/opendatasets
