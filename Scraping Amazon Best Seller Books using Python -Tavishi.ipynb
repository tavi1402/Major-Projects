# %% [markdown]
# # Scraping Amazon Best Seller Books using Python

# %% [markdown]
# ## Introduction about Web scrapping
#
# Web scraping, also called web data mining or web harvesting, Web scraping is the process of extract, parse, download and organize useful information from the web automatically.
#
# This extracted is in the form of an Excel spreadsheet or a CSV file, but the data can also be saved in other formats, such as a JSON file.
#
# Unlike screen scraping, which only copies pixels displayed on screen, web scraping extracts underlying HTML code and, with it, data stored in a database.

# %% [markdown]
# ![](https://i.imgur.com/nwQiy9e.jpg)

# %% [markdown]
# ## Introduction about GitHub
#
# GitHub, is a cloud based hosting service for software development projects that use the Git revision control system.GitHub is a social network for programmers.It is the world's largest coding community.Github allows you to take part in collaboration by forking projects, sending and pulling requests, and monitoring development.
#
#
# GitHub offers both paid plans for private repositories, and free accounts for open source projects.
#
#
# It offers the distributed version control and source code management (SCM) functionality of Git, plus its own features. It provides access control and several collaboration features such as bug tracking, feature requests, task management, continuous integration for every project.

# %% [markdown]
# ![](https://i.imgur.com/CKGbGYe.jpg)

# %% [markdown]
# #### Project outline
#
# - Here are the steps we'll follow:
# - We're going to scrape https://www.amazon.in/gp/bestsellers/books/
#
# - We'll first get the list of different genre. For each genre we'll get the genre name and genre page URL. For each genre we'll get the top 50 books in the genre by the genre page.
#
# - For each book we'll grab the Book Name, Author Name, Stars, Number of Reviews, Book_Type, Price and the Book URL.
#
# - For each genre we'll create the CSV file in the following format
#
# Book_Name,Author_Name,Book_URL,Edition_Type,Price,Star_Rating,Reviews
#
# Harry Potter and the Philosopher's Stone,J.K. Rowling,https://amazon.in/Harry-Potter-Philosophers-Stone-Rowling-ebook/dp/B019PIOJYU/ref=zg_bs_1318158031_1/000-0000000-0000000?pd_rd_i=B019PIOJYU&psc=1,Kindle Edition,₹299.00,4.7 out of 5 stars,"39,452"
#
# The Silent Patient: The record-breaking, multimillion copy Sunday Times bestselling thriller and Richard & Judy book club pick",Alex Michaelides,https://amazon.in/Silent-Patient-Alex-Michaelides/dp/1409181634/ref=zg_bs_1318158031_2/000-0000000-0000000?pd_rd_i=1409181634&psc=1,Paperback,₹279.00,4.5 out of 5 stars,"92,969"

# %% [markdown]
# ![](https://i.imgur.com/Zx5uZVq.png)

# %% [markdown]
# ## Tools used to scrape the list of topics from Github
#
# - Requests : to download the page
# - BS4 : to parse and extract information
# - Converting to a Pandas DataFrame

# %% [markdown]
# ## Requests
#
# The requests allows you to send HTTP requests using Python. The HTTP request returns a Response Object with all the response data (content, encoding, status, etc)
#
#
#
# ![](https://i.imgur.com/Ty6gVtb.jpg)

# %%
import requests

# %%
url='https://www.amazon.in/gp/bestsellers/books/'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
len(response.text)
# Out:
# 305080

# %%
page_content=response.text

# %%
page_content[0:500]
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completio'

# %%
with open('amazon_bestseller.html',"w") as f:
    f.write(page_content)

# %% [markdown]
# SCREENSHORT OF BESTSLLER

# %% [markdown]
# ## Use Beautiful Soup to parse and extract information
# - Parse and explore the structure of downloaded web pages using Beautiful soup.
#
# - Use the right properties and methods to extract the required information.
#
# - Create functions to extract from the page into lists and dictionaries.
#
# - (Optional) Use a REST API to acquire additional information if required.

# %%
from bs4 import BeautifulSoup
doc = BeautifulSoup(page_content, 'html.parser')

# %%
selection_class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8"
genre_title_tag=doc.find_all('div',{ 'class':selection_class})

# %% [markdown]
# ![](https://i.imgur.com/CJ0a06E.png)

# %%
len(genre_title_tag)
# Out:
# 35

# %%
#genre_title_tag[:3]

# %%
genre_title_tag=genre_title_tag[1:len(genre_title_tag)]
genre_title_tag[:3]
# Out:
# [<div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><a href="/gp/bestsellers/books/1318158031">Action &amp; Adventure</a></div>,
#  <div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><a href="/gp/bestsellers/books/1318052031">Arts, Film &amp; Photography</a></div>,
#  <div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><a href="/gp/bestsellers/books/1318064031">Biographies, Diaries &amp; True Accounts</a></div>]

# %% [markdown]
# ## Extracting tittles and urls of the genre

# %%
def get_topic_titles(doc):
    selection_class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8"
    genre_title_tag=doc.find_all('div',{ 'class':selection_class})
    topic_titles = []
    for tag in genre_title_tag:
        topic_titles.append(tag.text)
    return topic_titles

# %%
get_topic_titles(doc)
# Out:
# ['Books',
#  'Action & Adventure',
#  'Arts, Film & Photography',
#  'Biographies, Diaries & True Accounts',
#  'Business & Economics',
#  "Children's & Young Adult",
#  'Comics & Mangas',
#  'Computing, Internet & Digital Media',
#  'Crafts, Home & Lifestyle',
#  'Crime, Thriller & Mystery',
#  'Engineering',
#  'Exam Preparation',
#  'Fantasy, Horror & Science Fiction',
#  'Health, Family & Personal Development',
#  'Health, Fitness & Nutrition',
#  'Higher Education Textbooks',
#  'Historical Fiction',
#  'History',
#  'Humour',
#  'Language, Linguistics & Writing',
#  'Law',
#  'Literature & Fiction',
#  'Maps & Atlases',
#  'Medicine & Health Sciences',
#  'Politics',
#  'Reference',
#  'Religion',
#  'Romance',
#  'School Books',
#  'Science & Mathematics',
#  'Sciences, Technology & Medicine',
#  'Society & Social Sciences',
#  'Sports',
#  'Textbooks & Study Guides',
#  'Travel']

# %%
def get_topic_urls(doc):
    selection_class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8"
    genre_url_tag=doc.find_all('div',{ 'class':selection_class})
    #print(genre_url_tag)
    topic_urls = []
    base_url='https://www.amazon.in'
    for tag in genre_url_tag:
        try:
            topic_urls.append(base_url +  tag.find('a')['href'])
        except:
            topic_urls.append('No URL')
        #print(tag.find('a'))
        #topic_urls.append(base_url + tag.find('a')['href'])
    return topic_urls

# %%
urls=get_topic_urls(doc)
urls
# Out:
# ['No URL',
#  'https://www.amazon.in/gp/bestsellers/books/1318158031',
#  'https://www.amazon.in/gp/bestsellers/books/1318052031',
#  'https://www.amazon.in/gp/bestsellers/books/1318064031',
#  'https://www.amazon.in/gp/bestsellers/books/1318068031',
#  'https://www.amazon.in/gp/bestsellers/books/1318073031',
#  'https://www.amazon.in/gp/bestsellers/books/1318104031',
#  'https://www.amazon.in/gp/bestsellers/books/1318105031',
#  'https://www.amazon.in/gp/bestsellers/books/1318118031',
#  'https://www.amazon.in/gp/bestsellers/books/1318161031',
#  'https://www.amazon.in/gp/bestsellers/books/22960344031',
#  'https://www.amazon.in/gp/bestsellers/books/4149751031',
#  'https://www.amazon.in/gp/bestsellers/books/1402038031',
#  'https://www.amazon.in/gp/bestsellers/books/1318128031',
#  'https://www.amazon.in/gp/bestsellers/books/23033693031',
#  'https://www.amazon.in/gp/bestsellers/books/4149418031',
#  'https://www.amazon.in/gp/bestsellers/books/1318164031',
#  'https://www.amazon.in/gp/bestsellers/books/4149493031',
#  'https://www.amazon.in/gp/bestsellers/books/1318143031',
#  'https://www.amazon.in/gp/bestsellers/books/1318144031',
#  'https://www.amazon.in/gp/bestsellers/books/4149542031',
#  'https://www.amazon.in/gp/bestsellers/books/1318157031',
#  'https://www.amazon.in/gp/bestsellers/books/1318298031',
#  'https://www.amazon.in/gp/bestsellers/books/4149549031',
#  'https://www.amazon.in/gp/bestsellers/books/1318176031',
#  'https://www.amazon.in/gp/bestsellers/books/1318185031',
#  'https://www.amazon.in/gp/bestsellers/books/1318188031',
#  'https://www.amazon.in/gp/bestsellers/books/1318168031',
#  'https://www.amazon.in/gp/bestsellers/books/4149807031',
#  'https://www.amazon.in/gp/bestsellers/books/4149708031',
#  'https://www.amazon.in/gp/bestsellers/books/1318203031',
#  'https://www.amazon.in/gp/bestsellers/books/1318216031',
#  'https://www.amazon.in/gp/bestsellers/books/1318224031',
#  'https://www.amazon.in/gp/bestsellers/books/15417300031',
#  'https://www.amazon.in/gp/bestsellers/books/1318295031']

# %% [markdown]
# ## Import pandas to create dataframe

# %%
import pandas as pd

# %%
def scrape_topics():
    topics_url = 'https://www.amazon.in/gp/bestsellers/books/'
    response = requests.get(topics_url)
    if response.status_code != 200:
        raise Exception('Failed to load page {}'.format(topics_url))
    doc = BeautifulSoup(response.text, 'html.parser')
    topics_dict = {
        'title': get_topic_titles(doc),
        'url': get_topic_urls(doc)
    }
    return pd.DataFrame(topics_dict)

# %%
scrape_topics().drop(0,axis=0)
# Out:
#                                     title  \
# 1                      Action & Adventure
# 2                Arts, Film & Photography
# 3    Biographies, Diaries & True Accounts
# 4                    Business & Economics
# 5                Children's & Young Adult
# 6                         Comics & Mangas
# 7     Computing, Internet & Digital Media
# 8                Crafts, Home & Lifestyle
# 9               Crime, Thriller & Mystery
# 10                            Engineering
# 11                       Exam Preparation
# 12      Fantasy, Horror & Science Fiction
# 13  Health, Family & Personal Development
# 14            Health, Fitness & Nutrition
# 15             Higher Education Textbooks
# 16                     Historical Fiction
# 17                                History
# 18                                 Humour
# 19        Language, Linguistics & Writing
# 20                                    Law
# 21                   Literature & Fiction
# 22                         Maps & Atlases
# 23             Medicine & Health Sciences
# 24                               Politics
# 25                              Reference
# 26                               Religion
# 27                                Romance
# 28                           School Books
# 29                  Science & Mathematics
# 30        Sciences, Technology & Medicine
# 31              Society & Social Sciences
# 32                                 Sports
# 33               Textbooks & Study Guides
# 34                                 Travel
#
#                                                   url
# 1   https://www.amazon.in/gp/bestsellers/books/131...
# 2   https://www.amazon.in/gp/bestsellers/books/131...
# 3   https://www.amazon.in/gp/bestsellers/books/131...
# 4   https://www.amazon.in/gp/bestsellers/books/131...
# 5   https://www.amazon.in/gp/bestsellers/books/131...
# 6   https://www.amazon.in/gp/bestsellers/books/131...
# 7   https://www.amazon.in/gp/bestsellers/books/131...
# 8   https://www.amazon.in/gp/bestsellers/books/131...
# 9   https://www.amazon.in/gp/bestsellers/books/131...
# 10  https://www.amazon.in/gp/bestsellers/books/229...
# 11  https://www.amazon.in/gp/bestsellers/books/414...
# 12  https://www.amazon.in/gp/bestsellers/books/140...
# 13  https://www.amazon.in/gp/bestsellers/books/131...
# 14  https://www.amazon.in/gp/bestsellers/books/230...
# 15  https://www.amazon.in/gp/bestsellers/books/414...
# 16  https://www.amazon.in/gp/bestsellers/books/131...
# 17  https://www.amazon.in/gp/bestsellers/books/414...
# 18  https://www.amazon.in/gp/bestsellers/books/131...
# 19  https://www.amazon.in/gp/bestsellers/books/131...
# 20  https://www.amazon.in/gp/bestsellers/books/414...
# 21  https://www.amazon.in/gp/bestsellers/books/131...
# 22  https://www.amazon.in/gp/bestsellers/books/131...
# 23  https://www.amazon.in/gp/bestsellers/books/414...
# 24  https://www.amazon.in/gp/bestsellers/books/131...
# 25  https://www.amazon.in/gp/bestsellers/books/131...
# 26  https://www.amazon.in/gp/bestsellers/books/131...
# 27  https://www.amazon.in/gp/bestsellers/books/131...
# 28  https://www.amazon.in/gp/bestsellers/books/414...
# 29  https://www.amazon.in/gp/bestsellers/books/414...
# 30  https://www.amazon.in/gp/bestsellers/books/131...
# 31  https://www.amazon.in/gp/bestsellers/books/131...
# 32  https://www.amazon.in/gp/bestsellers/books/131...
# 33  https://www.amazon.in/gp/bestsellers/books/154...
# 34  https://www.amazon.in/gp/bestsellers/books/131...

# %% [markdown]
# ## Extracting information for all genre

# %%
genre_url='https://www.amazon.in/gp/bestsellers/books/1318158031'

# %%
response=requests.get(genre_url)

# %%
genre_doc = BeautifulSoup(response.text, 'html.parser')

# %%
div_tags= genre_doc.find_all('div',{'class':"zg-grid-general-faceout"})
#div_tags

# %%
import os
genre_doc = BeautifulSoup(response.text, 'html.parser')
books_dict_genre={
        'Book_Name':[],
        'Author_Name':[],
        'Book_URL':[],
        'Edition_Type':[],
        'Price':[],
        'Star_Rating':[],
        'Reviews':[]
    }    

def get_topic_page(genre_urls):
    # download the page
    genre_url='https://www.amazon.in/gp/bestsellers/books/1318158031'
    # check sucessful response
    response=requests.get(genre_urls)
    
    if response.status_code!=200:
        raise Exception('failed to load page{}'.format(genre_urls))
    # parse using BeautifulSoup
    topic_doc=BeautifulSoup(response.text, 'html.parser')
    #div_tags= genre_doc.find_all('div',{'class':"zg-grid-general-faceout"})
    return topic_doc


def genre_books_info(div_tags):
    #extracting book names
    Book_Name_tags =div_tags.find('span')
    #extracting author name of books 
    Author_Name_tags = div_tags.find('a', class_ = 'a-size-small a-link-child')
    #extracting books urls
    Book_URL = 'https://amazon.in' + div_tags.find('a', class_ = 'a-link-normal')['href']
    #extracting edition type of books
    Edition_Type_tags = div_tags.find('span', class_ = 'a-size-small a-color-secondary a-text-normal')
    #extracting price tag of book 
    Price_tags = div_tags.find('span', class_ = 'p13n-sc-price')
    #extracting star rating of books
    Star_Rating_tags = div_tags.find('span', class_ = 'a-icon-alt')
    #extracting review of books
    Reviews_tags = div_tags.find('span', class_ = 'a-size-small')
    return Book_Name_tags, Author_Name_tags, Book_URL, Edition_Type_tags, Price_tags, Star_Rating_tags, Reviews_tags
    
def book_name(genre_info):
    if genre_info[0] is not None:
        books_dict_genre['Book_Name'].append(genre_info[0].text)
    else:
        books_dict_genre['Book_Name'].append('Missing')
    return books_dict_genre

def author_name(genre_info):
    if genre_info[1] is not None:
        books_dict_genre['Author_Name'].append(genre_info[1].text)
    else:
        books_dict_genre['Author_Name'].append('Missing')
    return books_dict_genre  

def book_url(genre_info):
    if genre_info[2] is not None:
        books_dict_genre['Book_URL'].append(genre_info[2])
    else:
        books_dict_genre['Book_URL'].append('Missing')
    return books_dict_genre

def edition_type(genre_info) :   
    if genre_info[3] is not None:
        books_dict_genre['Edition_Type'].append(genre_info[3].text)
    else:
        books_dict_genre['Edition_Type'].append('Missing')
    return books_dict_genre 


def book_price(genre_info):     
    if genre_info[4] is not None:
        return books_dict_genre['Price'].append(genre_info[4].text)
    else:
        return books_dict_genre['Price'].append('Missing')
          
def star_rating(genre_info):
    if genre_info[5] is not None:
        books_dict_genre['Star_Rating'].append(genre_info[5].text)
    else:
        books_dict_genre['Star_Rating'].append('Missing') 
    return books_dict_genre    

def book_reviews(genre_info):
    if genre_info[6] is not None:
        books_dict_genre['Reviews'].append(genre_info[6].text)
    else:
        books_dict_genre['Reviews'].append('Missing')
    return books_dict_genre

def get_genre_books(genre_doc):
    div_selection_class = 'zg-grid-general-faceout'
    div_tags = genre_doc.find_all('div', class_ = div_selection_class ) # creating a dictionary   
    for i in range(0, len(div_tags)):
        genre_info = genre_books_info(div_tags[i])
        book_name(genre_info)
        author_name(genre_info)
        book_url(genre_info)
        edition_type(genre_info)
        book_price(genre_info)
        star_rating(genre_info)
        book_reviews(genre_info)  
    return pd.DataFrame(books_dict_genre)

get_genre_books(genre_doc)
# Out:
#                                             Book_Name  \
# 0            Harry Potter and the Philosopher's Stone
# 1                              The Magicians of Mazda
# 2              The Complete Novels of Sherlock Holmes
# 3                              The Magicians Of Mazda
# 4   The Silent Patient: The record-breaking, multi...
# 5                                   The Secret Garden
# 6             Harry Potter and the Chamber of Secrets
# 7                          Something I Never Told You
# 8           Harry Potter and the Order of the Phoenix
# 9                                     The Nightingale
# 10             Harry Potter and the Half-Blood Prince
# 11                    On Earth We're Briefly Gorgeous
# 12                Harry Potter and the Goblet of Fire
# 13           Harry Potter and the Prisoner of Azkaban
# 14  Harry Potter 1-3 Box Set: A Magical Adventure ...
# 15               Harry Potter and the Deathly Hallows
# 16       Diary of a Wimpy Kid: The Deep End (Book 15)
# 17  Circe: The International No. 1 Bestseller - Sh...
# 18                                     Deception Game
# 19                             Baby Touch: Tummy Time
# 20        BEYOND THE DARKNESS: The Malhotra Series #3
# 21           The Complete Adventures of Feluda Vol. 1
# 22          The Secret Of The Nagas (Shiva Trilogy-2)
# 23                    Spy x Family, Vol. 1 (Volume 1)
# 24                             The Enormous Crocodile
# 25  Favourite Stories of Courageous Girls: inspiri...
# 26                                One Arranged Murder
# 27         ஏகாந்த காதலா-1 (Anti Hero) (Tamil Edition)
# 28                                          Peter Pan
# 29                            Beach Read (Lead Title)
# 30  Crooked Kingdom Collector's Edition (Six of Cr...
# 31                            The Wind In The Willows
# 32  Beautiful World, Where Are You: from the inter...
# 33  Mindwandering: How It Can Improve Your Mood an...
# 34                                     The Cursed Gem
# 35                     The Spirits Of The Hill Castle
# 36                               Daughter of the Deep
# 37                    Aurangzeb: The Man and the Myth
# 38                    Spy x Family, Vol. 2 (Volume 2)
# 39  Westland Publications Meluha Ke Mritunjay (Imm...
# 40           Treasure Island (AmazonClassics Edition)
# 41    River God: The Egyptian Series 1 (Egypt Series)
# 42                                Midnight's Children
# 43                 Jim Corbett : Man Eaters of Kumaon
# 44                    Origin: (Robert Langdon Book 5)
# 45  29 Seconds: From the million-copy Sunday Times...
# 46         அணு அணுவாய் நெருங்குகிறாய் (Tamil Edition)
# 47                   Sila Nerangalil Sila Manidhargal
# 48  Fire and Blood: A History of the Targaryen Kin...
# 49                                Tales From My Heart
#
#                 Author_Name  \
# 0              J.K. Rowling
# 1             Ashwin Sanghi
# 2        Arthur Conan Doyle
# 3             Ashwin Sanghi
# 4          Alex Michaelides
# 5   Frances Hodgson Burnett
# 6              J.K. Rowling
# 7           Shravya Bhinder
# 8              J.K. Rowling
# 9            Kristin Hannah
# 10             J.K. Rowling
# 11              Ocean Vuong
# 12             J.K. Rowling
# 13             J.K. Rowling
# 14             J.K. Rowling
# 15             J.K. Rowling
# 16              Jeff Kinney
# 17          Madeline Miller
# 18             Meenu Pillai
# 19                 Ladybird
# 20                  Missing
# 21             Satyajit Ray
# 22           Amish Tripathi
# 23                  Missing
# 24               Roald Dahl
# 25                  Missing
# 26           Chetan  Bhagat
# 27                  Missing
# 28             J. M. Barrie
# 29              Emily Henry
# 30            Leigh Bardugo
# 31          Kenneth Grahame
# 32             Sally Rooney
# 33                Moshe Bar
# 34         Ashwini Malhotra
# 35                  Missing
# 36             Rick Riordan
# 37          Audrey Truschke
# 38             Tatsuya Endo
# 39           Amish Tripathi
# 40   Robert Louis Stevenson
# 41             Wilbur Smith
# 42           Salman Rushdie
# 43              Jim Corbett
# 44                Dan Brown
# 45               T.M. Logan
# 46              சஹானா "சனா"
# 47                  Missing
# 48       George R.R. Martin
# 49              Ruskin Bond
#
#                                              Book_URL    Edition_Type  \
# 0   https://amazon.in/Harry-Potter-Philosophers-St...  Kindle Edition
# 1   https://amazon.in/Magicians-Mazda-Ashwin-Sangh...       Paperback
# 2   https://amazon.in/Complete-Novels-Sherlock-Hol...       Paperback
# 3   https://amazon.in/Magicians-Mazda-Ashwin-Sangh...  Kindle Edition
# 4   https://amazon.in/Silent-Patient-Alex-Michaeli...       Paperback
# 5   https://amazon.in/Secret-Garden-Frances-Hodgso...       Paperback
# 6   https://amazon.in/Harry-Potter-Chamber-Secrets...  Kindle Edition
# 7   https://amazon.in/Something-I-Never-Told-You/d...       Paperback
# 8   https://amazon.in/Harry-Potter-Order-Phoenix-R...  Kindle Edition
# 9   https://amazon.in/Nightingale-Kristin-Hannah/d...       Paperback
# 10  https://amazon.in/Harry-Potter-Half-Blood-Prin...  Kindle Edition
# 11  https://amazon.in/Earth-Were-Briefly-Gorgeous/...       Paperback
# 12  https://amazon.in/Harry-Potter-Goblet-Fire-Row...  Kindle Edition
# 13  https://amazon.in/Harry-Potter-Prisoner-Azkaba...  Kindle Edition
# 14  https://amazon.in/Harry-Potter-1-3-Box-Set/dp/...       Paperback
# 15  https://amazon.in/Harry-Potter-Deathly-Hallows...  Kindle Edition
# 16  https://amazon.in/Diary-Wimpy-Kid-Deep-Book/dp...       Paperback
# 17  https://amazon.in/Circe-International-Bestsell...       Paperback
# 18  https://amazon.in/Deception-Game-Meenu-Pillai-...  Kindle Edition
# 19  https://amazon.in/Baby-Touch-Tummy-Time/dp/024...      Board book
# 20  https://amazon.in/BEYOND-DARKNESS-Malhotra-Yuk...  Kindle Edition
# 21  https://amazon.in/Complete-Adventures-Feluda-V...       Paperback
# 22  https://amazon.in/Secret-Nagas-Shiva-Trilogy-2...       Paperback
# 23  https://amazon.in/Spy-Family-Vol-Tatsuya-Endo/...       Paperback
# 24  https://amazon.in/Enormous-Crocodile-Dahl-Fict...       Paperback
# 25  https://amazon.in/Favourite-Stories-Courageous...       Paperback
# 26  https://amazon.in/One-Arranged-Murder-Chetan-B...  Kindle Edition
# 27  https://amazon.in/%E0%AE%8F%E0%AE%95%E0%AE%BE%...  Kindle Edition
# 28  https://amazon.in/Peter-Pan-J-M-Barrie/dp/9386...       Paperback
# 29  https://amazon.in/Beach-Read-laugh-out-loud-es...       Paperback
# 30  https://amazon.in/Crooked-Kingdom-Collectors-S...       Hardcover
# 31  https://amazon.in/Wind-Willows-Kenneth-Grahame...       Paperback
# 32  https://amazon.in/Beautiful-World-Where-Are-Yo...       Paperback
# 33  https://amazon.in/Mindwandering-Improve-Your-B...       Paperback
# 34  https://amazon.in/Cursed-Gem-Ashwini-Malhotra-...  Kindle Edition
# 35  https://amazon.in/Spirits-Hill-Castle-Naami-eb...  Kindle Edition
# 36  https://amazon.in/Daughter-Deep-Rick-Riordan/d...       Paperback
# 37  https://amazon.in/Aurangzeb-Man-Myth-Audrey-Tr...       Paperback
# 38  https://amazon.in/Spy-Family-Vol-Tatsuya-Endo/...       Paperback
# 39  https://amazon.in/Meluha-Ke-Mritunjay-Immortal...       Paperback
# 40  https://amazon.in/Treasure-Island-AmazonClassi...  Kindle Edition
# 41  https://amazon.in/River-God-Egyptian-1-Egypt-e...  Kindle Edition
# 42  https://amazon.in/Midnights-Children-Salman-Ru...       Paperback
# 43  https://amazon.in/Man-Eaters-Kumaon-Jim-Corbet...       Paperback
# 44  https://amazon.in/Origin-Robert-Langdon-Dan-Br...       Paperback
# 45  https://amazon.in/29-Seconds-gripping-twisty-p...  Kindle Edition
# 46  https://amazon.in/%E0%AE%85%E0%AE%A3%E0%AF%81-...  Kindle Edition
# 47  https://amazon.in/Sila-Nerangalil-Manidhargal-...       Hardcover
# 48  https://amazon.in/Fire-Blood-Targaryen-Conquer...       Hardcover
# 49  https://amazon.in/Tales-My-Heart-Ruskin-Bond/d...       Paperback
#
#         Price         Star_Rating            Reviews
# 0     ₹299.00  4.7 out of 5 stars             41,751
# 1     ₹264.00  5.0 out of 5 stars                  7
# 2     ₹139.00  4.5 out of 5 stars             13,230
# 3     ₹326.80  5.0 out of 5 stars                  7
# 4     ₹285.00  4.5 out of 5 stars            100,341
# 5     ₹120.00  4.4 out of 5 stars             10,185
# 6     ₹299.00  4.7 out of 5 stars             33,962
# 7     ₹150.00  4.3 out of 5 stars              1,765
# 8     ₹299.00  4.7 out of 5 stars             22,478
# 9     ₹296.00  4.6 out of 5 stars             76,977
# 10    ₹299.00  4.7 out of 5 stars             26,613
# 11    ₹269.00  4.4 out of 5 stars              8,019
# 12    ₹299.00  4.7 out of 5 stars             24,152
# 13    ₹222.30  4.7 out of 5 stars             27,019
# 14  ₹1,052.00  4.7 out of 5 stars              2,394
# 15    ₹299.00  4.7 out of 5 stars             27,746
# 16    ₹245.00  4.7 out of 5 stars              8,816
# 17    ₹334.00  4.5 out of 5 stars             27,911
# 18     ₹99.00  4.4 out of 5 stars                121
# 19    ₹333.00  4.5 out of 5 stars              1,133
# 20     ₹99.00  4.6 out of 5 stars      Yuktha Asrani
# 21    ₹357.00  4.7 out of 5 stars                852
# 22    ₹344.00  4.6 out of 5 stars              7,666
# 23    ₹685.00  4.9 out of 5 stars       Tatsuya Endo
# 24    ₹230.93  4.6 out of 5 stars              3,189
# 25    ₹349.00  4.4 out of 5 stars  Louisa May Alcott
# 26    ₹125.00  4.4 out of 5 stars             18,728
# 27    ₹100.00  5.0 out of 5 stars         பாலா  ராஜி
# 28    ₹119.00  4.4 out of 5 stars              2,904
# 29    ₹279.00  4.2 out of 5 stars             23,585
# 30    ₹638.00  4.7 out of 5 stars             16,870
# 31    ₹102.00  4.4 out of 5 stars              5,019
# 32    ₹499.00  4.1 out of 5 stars              8,984
# 33    ₹425.00  4.5 out of 5 stars                  9
# 34     ₹99.00  4.5 out of 5 stars                 31
# 35    ₹223.00  3.2 out of 5 stars         E.A. Naami
# 36    ₹406.00  4.7 out of 5 stars              1,786
# 37    ₹221.00  4.2 out of 5 stars                886
# 38    ₹699.00  4.9 out of 5 stars              3,805
# 39    ₹365.00  4.5 out of 5 stars              2,804
# 40     ₹90.25  4.3 out of 5 stars              9,127
# 41    ₹284.05  4.5 out of 5 stars              2,237
# 42    ₹339.00  4.4 out of 5 stars              2,585
# 43    ₹140.00  4.6 out of 5 stars              1,298
# 44    ₹297.00  4.4 out of 5 stars             29,167
# 45    ₹292.74  4.3 out of 5 stars              4,017
# 46    ₹449.00  3.9 out of 5 stars                 44
# 47    ₹290.00  4.5 out of 5 stars        Jayakanthan
# 48    ₹349.00  4.5 out of 5 stars             10,623
# 49    ₹199.00  4.6 out of 5 stars                296

# %% [markdown]
# ### Extracting book names of book Harry Potter of genre action and adventure
# ![](https://i.imgur.com/mwpanA5.png)

# %% [markdown]
# ### Extracting author name of book Harry Potter of genre action and adventure
#
# ![](https://i.imgur.com/8QGVBYl.png)

# %% [markdown]
# ### Extracting book urls of book Harry Potter of genre action and adventure
# ![](https://i.imgur.com/ZuD98Ej.png)

# %% [markdown]
# ### Extracting book edition type of book Harry Potter of genre action and adventure
# ![](https://i.imgur.com/FZmwnmQ.png)

# %% [markdown]
# ### Extracting stars of book Harry Potter of genre action and adventure
# ![](https://i.imgur.com/j6SGsQT.png)

# %% [markdown]
# ### Extracting reviews of book Harry Potter of genre action and adventure
#
# ![](https://i.imgur.com/pggNwnm.png)

# %%
def scrape_genre(genre_url, path):
    if os.path.exists(path):
        print('The file {} already exists.. Skipping...'.format(path))
        return
    genre_df = get_genre_books(get_topic_page(genre_url))
    genre_df.to_csv(path, index = None)
    
def scrape_genre_books():
    print('Scraping list of book genres')
    genres_df = scrape_topics()
    genres_df = genres_df.drop(0,axis=0)
    #print(genres_df)
    os.makedirs('data', exist_ok = True)
    for index, row in genres_df.iterrows():
        print('Scraping bestselling books for the genre "{}"'.format(row['title']))
        scrape_genre(row['url'], 'data/{}.csv'.format(row['title']))

# %%
scrape_genre_books()
# Out:
# Scraping list of book genres
# Scraping bestselling books for the genre "Action & Adventure"
# The file data/Action & Adventure.csv already exists.. Skipping...
# Scraping bestselling books for the genre "Arts, Film & Photography"
# The file data/Arts, Film & Photography.csv already exists.. Skipping...
# Scraping bestselling books for the genre "Biographies, Diaries & True Accounts"
# The file data/Biographies, Diaries & True Accounts.csv already exists.. Skipping...
# Scraping bestselling books for the genre "Business & Economics"
# Scraping bestselling books for the genre "Children's & Young Adult"
# Scraping bestselling books for the genre "Comics & Mangas"
# Scraping bestselling books for the genre "Computing, Internet & Digital Media"
# Scraping bestselling books for the genre "Crafts, Home & Lifestyle"
# Scraping bestselling books for the genre "Crime, Thriller & Mystery"
# Scraping bestselling books for the genre "Engineering"
# Scraping bestselling books for the genre "Exam Preparation"
# Scraping bestselling books for the genre "Fantasy, Horror & Science Fiction"
# Scraping bestselling books for the genre "Health, Family & Personal Development"
# Scraping bestselling books for the genre "Health, Fitness & Nutrition"
# Scraping bestselling books for the genre "Higher Education Textbooks"
# Scraping bestselling books for the genre "Historical Fiction"
# Scraping bestselling books for the genre "History"
# Scraping bestselling books for the genre "Humour"
# Scraping bestselling books for the genre "Language, Linguistics & Writing"
# Scraping bestselling books for the genre "Law"
# Scraping bestselling books for the genre "Literature & Fiction"
# Scraping bestselling books for the genre "Maps & Atlases"
# Scraping bestselling books for the genre "Medicine & Health Sciences"
# Scraping bestselling books for the genre "Politics"
# Scraping bestselling books for the genre "Reference"
# Scraping bestselling books for the genre "Religion"
# Scraping bestselling books for the genre "Romance"
# Scraping bestselling books for the genre "School Books"
# Scraping bestselling books for the genre "Science & Mathematics"
# Scraping bestselling books for the genre "Sciences, Technology & Medicine"
# Scraping bestselling books for the genre "Society & Social Sciences"
# Scraping bestselling books for the genre "Sports"
# Scraping bestselling books for the genre "Textbooks & Study Guides"
# Scraping bestselling books for the genre "Travel"

# %% [markdown]
# ### Created data folder
# ![](https://i.imgur.com/35lLQnn.png)

# %% [markdown]
# ### Files stored in data folder
#
# ![](https://i.imgur.com/Xi6IkuN.png)

# %% [markdown]
# ### The data is stored in csv format
# ![](https://i.imgur.com/wj2igmU.png)

# %% [markdown]
# ## Summary
#
# ### What we have done so far was
#
# - Install and import libraries
#
# - Download and Parse the Bestseller HTML page source code using request and Beautifulsoup to get item categories topics URL.
#
# - Extract the topic(genre name),genre urls
#
# - Extract information from each page
#
# - Combine the extracted information Extract information from each page’s data in a Python Dictionaries
#
# - Save the information data to CSV file Using Pandas library
#
# - By the end of the project, we’ll create a CSV file in the following format:
#
#
# Book_Name,Author_Name,Book_URL,Edition_Type,Price,Star_Rating,Reviews
#
# Harry Potter and the Philosopher's Stone,J.K. Rowling,https://amazon.in/Harry-Potter-Philosophers-Stone-Rowling-ebook/dp/B019PIOJYU/ref=zg_bs_1318158031_1/000-0000000-0000000?pd_rd_i=B019PIOJYU&psc=1,Kindle Edition,₹299.00,4.7 out of 5 stars,"39,452"
#
# The Silent Patient: The record-breaking, multimillion copy Sunday Times bestselling thriller and Richard & Judy book club pick",Alex Michaelides,https://amazon.in/Silent-Patient-Alex-Michaelides/dp/1409181634/ref=zg_bs_1318158031_2/000-0000000-0000000?pd_rd_i=1409181634&psc=1,Paperback,₹279.00,4.5 out of 5 stars,"92,969"
# ```

# %% [markdown]
# ## References
#
# Here is some link to learn more about the used libraries:
#
# - request- (https://docs.python-requests.org/en/latest/)
# - Beautiful Soup- (https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - w3school- (https://www.w3schools.com/python/)
# - pandas-( https://www.w3schools.com/python/pandas/default.asp)
# - itertools.chain-(https://www.geeksforgeeks.org/python-itertools-chain/)
